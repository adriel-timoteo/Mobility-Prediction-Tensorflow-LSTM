# %% [markdown]
# <h2>FINAL DATA PREPROCESSING & MODEL TRAINING</h2>
#
# Script ini digunakan untuk mempreprocess data menjadi data final yang dapat digunakan untuk training model, dan training model LSTM itu sendiri. Secara umum, script ini meliputi:
# <h4>Data Preprocessing</h4>
# - Padding & Truncating data, pada dasarnya memastikan seluruh trj_id memiliki jumlah data yang sama, yakni 20 data, dengan menambahkan data yang kurang dengan 0 dan memotong data yang kelebihan dan mengambil 20 data paling belakang.
# - Membagi data menjadi X (koordinat, keceptan, dll yang dimasukkan ke model untuk melatih model) dan y (koordinat yang benar untuk dibandingkan dengan koordinat hasil prediksi model). y akan diambil dari koordinat terakhir tiap trajectory.
# - Membagi data menjadi training data dan testing data, dengan pembagian 90%/10%.
# <br/>
# <h4>Model Training</h4>
# - Mendefinisikan dan melatih model LSTM berdasarkan data yang telah siap.
# - Arsitektur, epoch, loss, optimizer, dan dll dapat dengan bebas diubah-ubah untuk mencoba model lain.
# <br/>
# Jika ingin melihat performa model pertama yang telah saya latih, maka model itu sudah disave dalam folder models dengan nama model_v1.keras. Model dapat ditest menggunakan script Model Test.ipynb

# %%
## Import libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import datetime
import keras

# %%
# Load Tensorboard
# %load_ext tensorboard

# %%
## Read data from csv
#resampled_data = pd.read_csv('clean_data.csv', index_col='trj_id').drop('Unnamed: 1', axis=1)
resampled_data = pd.read_parquet('clean_non_resampled_data.parquet')
print(resampled_data)
# Out:
#           rawlat      rawlng  speed  bearing  minute_of_hour  hour_of_day  \
# trj_id
# 2      -6.248311  106.930447  11.35       88              51            0
# 2      -6.248345  106.930673  12.43       87              51            0
# 2      -6.248374  106.930931  13.83       84              51            0
# 2      -6.248391  106.931061  14.29       85              51            0
# 2      -6.248410  106.931184  14.58       87              51            0
# ...          ...         ...    ...      ...             ...          ...
# 55995  -6.178844  106.841960   0.00        0              57            4
# 55995  -6.178844  106.841960   0.00        0              57            4
# 55995  -6.178844  106.841961   0.00        0              57            4
# 55995  -6.178845  106.841963   0.00        0              57            4
# 55995  -6.178845  106.841964   0.00        0              57            4
#
#         day_of_week
# trj_id
# 2                 1
# 2                 1
# 2                 1
# 2                 1
# 2                 1
# ...             ...
# 55995             6
# 55995             6
# 55995             6
# 55995             6
# 55995             6
#
# [34839771 rows x 7 columns]

# %%
# Optimize Dataset Further
counts = resampled_data.groupby(level='trj_id').size()
filtered_df = resampled_data[resampled_data.index.get_level_values('trj_id').isin(counts[counts >= 50].index)]
print(filtered_df)
# Out:
#           rawlat      rawlng  speed  bearing  minute_of_hour  hour_of_day  \
# trj_id
# 2      -6.248311  106.930447  11.35       88              51            0
# 2      -6.248345  106.930673  12.43       87              51            0
# 2      -6.248374  106.930931  13.83       84              51            0
# 2      -6.248391  106.931061  14.29       85              51            0
# 2      -6.248410  106.931184  14.58       87              51            0
# ...          ...         ...    ...      ...             ...          ...
# 55995  -6.178844  106.841960   0.00        0              57            4
# 55995  -6.178844  106.841960   0.00        0              57            4
# 55995  -6.178844  106.841961   0.00        0              57            4
# 55995  -6.178845  106.841963   0.00        0              57            4
# 55995  -6.178845  106.841964   0.00        0              57            4
#
#         day_of_week
# trj_id
# 2                 1
# 2                 1
# 2                 1
# 2                 1
# 2                 1
# ...             ...
# 55995             6
# 55995             6
# 55995             6
# 55995             6
# 55995             6
#
# [34738878 rows x 7 columns]

# %%
# Pad and truncate the timestamps in the dataframe
# Ini buat kita samain input modelnya, gw potong timestampnya jadi pasti ada 60 timestamp per sample. Kalo lebih dipotong, kalo kurang ditambahin 0 di depannya
# Pad value None --> pake koordinat pertama

def pad_truncate_dataframe(df, max_len, padding='pre', truncating='post', pad_value=None):
  # Split the dataframe by samples (first level of multi-index)
  samples = df.groupby(level=0)

  # Define a function to pad/truncate a single sample
  def pad_truncate_sample(sample):
    # Extract the values from a single sample
    values = sample.values
    first_element = values[0]
    first_element[3] = 0
    first_element[4] = 0

    # Pad/truncate automatically using pad_sequences
    if pad_value == None:
      padded_truncated = tf.keras.preprocessing.sequence.pad_sequences(
          [values], maxlen=max_len, padding=padding, truncating=truncating, value=first_element, dtype='float64'
      )[0]
    else:
      padded_truncated = tf.keras.preprocessing.sequence.pad_sequences(
          [values], maxlen=max_len, padding=padding, truncating=truncating, value=pad_value, dtype='float64'
      )[0]

    # Convert back to pandas dataframe
    return pd.DataFrame(padded_truncated, columns=sample.columns)

  # Apply the function to each sample and recreate the multi-index dataframe
  padded_df = samples.apply(pad_truncate_sample)
  return padded_df

df_new = pad_truncate_dataframe(filtered_df, 70)

# %%
## Convert the multi index dataframe to a numpy 3D array for better integration to TensorFlow (samples, timesteps, features)
numpy_data = df_new.to_xarray().to_array().to_numpy()
numpy_data = np.transpose(numpy_data, (1, 2, 0))
numpy_data.shape # Should be (55994, 21, 6) if 55994 samples, 21 timesteps, and 6 features
# Out:
# (45065, 70, 7)

# %%
output_steps = 10

## Split the data to x (feature values) and y (target values)
simple_data = numpy_data[:, :, [0, 1]]
x_data = simple_data[:, :-output_steps, :]
y_data = simple_data[:, -output_steps:, 0:2]

# %%
# Split the data to train and test splits (train to train the model, test to test the model on new data after trained)
test_size = 0.1

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=test_size)

# %%
## Define normalization layer
normalize_layer = tf.keras.layers.Normalization(axis=-1)
denormalize_layer = tf.keras.layers.Normalization(axis=-1, invert=True)

normalize_layer.adapt(simple_data)
denormalize_layer.adapt(simple_data[:, :, 0:2])

normalize_weights = normalize_layer.get_weights()
mean_variance = np.array([normalize_weights[0][0:2], normalize_weights[1][0:2]])

# %%
## Save test data for model testing
np.save('x_test.npy', x_test)
np.save('y_test.npy', y_test)
np.save('x_train.npy', x_train)
np.save('y_train.npy', y_train)
np.save('simple_data.npy', simple_data)

# %%
## Define custom metric(s)
@keras.saving.register_keras_serializable(package="custom_metrics", name="avg_m_diff")
def avg_m_diff(y_true, y_pred):
    # Ensure the input tensors have the correct shape
    assert y_true.shape == y_pred.shape
    assert y_true.shape[2] == 2
    
    def haversine_distance(lat1, lon1, lat2, lon2):
        # Radius of the Earth in meters
        R = 6371000.0
        
        # Convert latitude and longitude from degrees to radians
        lat1 = lat1 * (tf.constant(3.141592653589793) / 180.0)
        lon1 = lon1 * (tf.constant(3.141592653589793) / 180.0)
        lat2 = lat2 * (tf.constant(3.141592653589793) / 180.0)
        lon2 = lon2 * (tf.constant(3.141592653589793) / 180.0)
        
        # Compute differences
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        
        # Haversine formula
        a = tf.math.sin(dlat / 2)**2 + tf.math.cos(lat1) * tf.math.cos(lat2) * tf.math.sin(dlon / 2)**2
        c = 2 * tf.math.atan2(tf.math.sqrt(a), tf.math.sqrt(1 - a))
        
        # Distance in meters
        distance = R * c
        
        return distance
    
    # Reshape the tensors to 2D arrays for easier manipulation
    y_true_flat = tf.reshape(y_true, [-1, 2])
    y_pred_flat = tf.reshape(y_pred, [-1, 2])
    
    # Split the coordinates into separate tensors
    lat_true, lon_true = tf.split(y_true_flat, num_or_size_splits=2, axis=1)
    lat_pred, lon_pred = tf.split(y_pred_flat, num_or_size_splits=2, axis=1)
    
    # Calculate the distance for each pair of points
    distances = haversine_distance(lat_true, lon_true, lat_pred, lon_pred)
    
    # Calculate the average distance
    average_distance = tf.reduce_mean(distances)
    
    return average_distance

# %%
input_steps = 60
num_features = 2
num_targets = 2

# Clear any previous models
tf.keras.backend.clear_session()

# Define the model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Input(shape=(input_steps, num_features)))
model.add(normalize_layer)
model.add(tf.keras.layers.LSTM(64))
model.add(tf.keras.layers.Dense(num_targets * output_steps))
model.add(tf.keras.layers.Reshape([output_steps, num_targets]))
model.add(denormalize_layer)

# Define optimizer
lr = 1e-3
opt = tf.keras.optimizers.Adam(learning_rate=lr)

model.compile(loss='huber', optimizer=opt, metrics=['mae', 'mse', avg_m_diff, 'root_mean_squared_error'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\adrie\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\backend\common\global_state.py:74: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)   │ (None, 60, 2)          │             5 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 32)             │         4,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 20)             │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 10, 2)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ normalization_1 (Normalization) │ (None, 10, 2)          │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,150 (20.12 KB)
#  Trainable params: 5,140 (20.08 KB)
#  Non-trainable params: 10 (48.00 B)

# %%
## Define LR scheduling (optional if want to use or not)
start_lr = lr
min_lr = 0.00001
max_lr = 0.001
rampup_epochs = 0
sustain_epochs = 0
exp_decay = 0.0

# Define the scheduling function
def schedule(epoch):
  def lr(epoch, start_lr, min_lr, max_lr, rampup_epochs, sustain_epochs, exp_decay):
    if epoch < rampup_epochs:
      lr = (max_lr - start_lr)/rampup_epochs * epoch + start_lr
    elif epoch < rampup_epochs + sustain_epochs:
      lr = max_lr
    else:
      lr = (max_lr - min_lr) * exp_decay**(epoch-rampup_epochs-sustain_epochs) + min_lr
    return lr
  return lr(epoch, start_lr, min_lr, max_lr, rampup_epochs, sustain_epochs, exp_decay)

# %%
## Define callbacks and fit the model
log_dir = "logs/fit/v6_2_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', patience=200)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(schedule)

model.fit(
  x=x_train, 
  y=y_train,
  epochs=1000,
  validation_data=(x_test, y_test),
  callbacks=[tensorboard_callback, early_stopping,]) #Can add lr_scheduler

model.evaluate(x_test, y_test)
# Out:
# Epoch 1/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 19ms/step - avg_m_diff: 3377.2061 - loss: 0.0010 - mae: 0.0188 - mse: 0.0020 - root_mean_squared_error: 0.0409 - val_avg_m_diff: 245.9202 - val_loss: 1.5253e-05 - val_mae: 0.0014 - val_mse: 3.0506e-05 - val_root_mean_squared_error: 0.0055
# Epoch 2/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 179.5875 - loss: 4.4652e-06 - mae: 0.0010 - mse: 8.9304e-06 - root_mean_squared_error: 0.0030 - val_avg_m_diff: 117.9398 - val_loss: 2.6995e-06 - val_mae: 6.7526e-04 - val_mse: 5.3991e-06 - val_root_mean_squared_error: 0.0023
# Epoch 3/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 135.0188 - loss: 1.4542e-06 - mae: 7.7846e-04 - mse: 2.9084e-06 - root_mean_squared_error: 0.0017 - val_avg_m_diff: 102.0482 - val_loss: 1.0311e-06 - val_mae: 5.8250e-04 - val_mse: 2.0621e-06 - val_root_mean_squared_error: 0.0014
# Epoch 4/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 118.1273 - loss: 8.0032e-07 - mae: 6.8010e-04 - mse: 1.6006e-06 - root_mean_squared_error: 0.0013 - val_avg_m_diff: 82.7244 - val_loss: 6.6644e-07 - val_mae: 4.7505e-04 - val_mse: 1.3329e-06 - val_root_mean_squared_error: 0.0012
# Epoch 5/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - avg_m_diff: 106.3535 - loss: 7.6164e-07 - mae: 6.1040e-04 - mse: 1.5233e-06 - root_mean_squared_error: 0.0012 - val_avg_m_diff: 76.5529 - val_loss: 3.9434e-07 - val_mae: 4.4047e-04 - val_mse: 7.8867e-07 - val_root_mean_squared_error: 8.8807e-04
# Epoch 6/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - avg_m_diff: 80.8654 - loss: 3.2906e-07 - mae: 4.6254e-04 - mse: 6.5812e-07 - root_mean_squared_error: 8.0508e-04 - val_avg_m_diff: 86.5363 - val_loss: 5.0313e-07 - val_mae: 4.8496e-04 - val_mse: 1.0063e-06 - val_root_mean_squared_error: 0.0010
# Epoch 7/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 113.7712 - loss: 7.5394e-07 - mae: 6.5093e-04 - mse: 1.5079e-06 - root_mean_squared_error: 0.0012 - val_avg_m_diff: 145.1308 - val_loss: 8.1300e-07 - val_mae: 8.2485e-04 - val_mse: 1.6260e-06 - val_root_mean_squared_error: 0.0013
# Epoch 8/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 79.4770 - loss: 2.8696e-07 - mae: 4.5156e-04 - mse: 5.7393e-07 - root_mean_squared_error: 7.5379e-04 - val_avg_m_diff: 77.5712 - val_loss: 3.4052e-07 - val_mae: 4.3836e-04 - val_mse: 6.8104e-07 - val_root_mean_squared_error: 8.2525e-04
# Epoch 9/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - avg_m_diff: 75.1360 - loss: 2.3222e-07 - mae: 4.3162e-04 - mse: 4.6444e-07 - root_mean_squared_error: 6.7890e-04 - val_avg_m_diff: 95.4483 - val_loss: 5.5031e-07 - val_mae: 5.6732e-04 - val_mse: 1.1006e-06 - val_root_mean_squared_error: 0.0010
# Epoch 10/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 86.4515 - loss: 3.7629e-07 - mae: 4.9789e-04 - mse: 7.5258e-07 - root_mean_squared_error: 8.5556e-04 - val_avg_m_diff: 58.9664 - val_loss: 1.3499e-07 - val_mae: 3.3534e-04 - val_mse: 2.6999e-07 - val_root_mean_squared_error: 5.1961e-04
# Epoch 11/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - avg_m_diff: 70.6127 - loss: 1.9442e-07 - mae: 4.0332e-04 - mse: 3.8884e-07 - root_mean_squared_error: 6.1978e-04 - val_avg_m_diff: 73.0571 - val_loss: 1.8650e-07 - val_mae: 4.2165e-04 - val_mse: 3.7301e-07 - val_root_mean_squared_error: 6.1075e-04
# Epoch 12/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 69.7383 - loss: 2.2059e-07 - mae: 3.9767e-04 - mse: 4.4118e-07 - root_mean_squared_error: 6.6014e-04 - val_avg_m_diff: 60.9924 - val_loss: 1.2960e-07 - val_mae: 3.4534e-04 - val_mse: 2.5921e-07 - val_root_mean_squared_error: 5.0913e-04
# Epoch 13/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 77.7328 - loss: 2.7714e-07 - mae: 4.4138e-04 - mse: 5.5427e-07 - root_mean_squared_error: 7.3164e-04 - val_avg_m_diff: 52.2277 - val_loss: 1.0019e-07 - val_mae: 2.9519e-04 - val_mse: 2.0037e-07 - val_root_mean_squared_error: 4.4763e-04
# Epoch 14/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 58.6410 - loss: 1.4547e-07 - mae: 3.3271e-04 - mse: 2.9094e-07 - root_mean_squared_error: 5.3469e-04 - val_avg_m_diff: 53.9041 - val_loss: 1.1124e-07 - val_mae: 3.0363e-04 - val_mse: 2.2249e-07 - val_root_mean_squared_error: 4.7169e-04
# Epoch 15/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 65.7759 - loss: 1.9611e-07 - mae: 3.7460e-04 - mse: 3.9222e-07 - root_mean_squared_error: 6.2037e-04 - val_avg_m_diff: 53.0450 - val_loss: 1.0279e-07 - val_mae: 2.9792e-04 - val_mse: 2.0557e-07 - val_root_mean_squared_error: 4.5340e-04
# Epoch 16/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - avg_m_diff: 65.3268 - loss: 1.5432e-07 - mae: 3.6831e-04 - mse: 3.0864e-07 - root_mean_squared_error: 5.4880e-04 - val_avg_m_diff: 52.9678 - val_loss: 9.8186e-08 - val_mae: 2.9820e-04 - val_mse: 1.9637e-07 - val_root_mean_squared_error: 4.4314e-04
# Epoch 17/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 56.0260 - loss: 1.5534e-07 - mae: 3.1873e-04 - mse: 3.1068e-07 - root_mean_squared_error: 5.5034e-04 - val_avg_m_diff: 53.1757 - val_loss: 1.0376e-07 - val_mae: 3.0390e-04 - val_mse: 2.0752e-07 - val_root_mean_squared_error: 4.5554e-04
# Epoch 18/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 29s 23ms/step - avg_m_diff: 55.5586 - loss: 1.0208e-07 - mae: 3.1476e-04 - mse: 2.0417e-07 - root_mean_squared_error: 4.5045e-04 - val_avg_m_diff: 83.9701 - val_loss: 2.4549e-07 - val_mae: 4.6173e-04 - val_mse: 4.9099e-07 - val_root_mean_squared_error: 7.0070e-04
# Epoch 19/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 61.5817 - loss: 1.6437e-07 - mae: 3.4984e-04 - mse: 3.2874e-07 - root_mean_squared_error: 5.6785e-04 - val_avg_m_diff: 55.1798 - val_loss: 9.5005e-08 - val_mae: 3.1671e-04 - val_mse: 1.9001e-07 - val_root_mean_squared_error: 4.3590e-04
# Epoch 20/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 56.9162 - loss: 1.1372e-07 - mae: 3.2306e-04 - mse: 2.2743e-07 - root_mean_squared_error: 4.7317e-04 - val_avg_m_diff: 51.8772 - val_loss: 9.6113e-08 - val_mae: 2.9390e-04 - val_mse: 1.9223e-07 - val_root_mean_squared_error: 4.3844e-04
# Epoch 21/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 57.6644 - loss: 1.2643e-07 - mae: 3.2771e-04 - mse: 2.5287e-07 - root_mean_squared_error: 5.0060e-04 - val_avg_m_diff: 102.5920 - val_loss: 4.1765e-07 - val_mae: 5.8093e-04 - val_mse: 8.3531e-07 - val_root_mean_squared_error: 9.1395e-04
# Epoch 22/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 66.1686 - loss: 1.7842e-07 - mae: 3.7144e-04 - mse: 3.5684e-07 - root_mean_squared_error: 5.8392e-04 - val_avg_m_diff: 81.1106 - val_loss: 2.5029e-07 - val_mae: 4.7724e-04 - val_mse: 5.0058e-07 - val_root_mean_squared_error: 7.0751e-04
# Epoch 23/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 66.7972 - loss: 1.7369e-07 - mae: 3.8157e-04 - mse: 3.4737e-07 - root_mean_squared_error: 5.8677e-04 - val_avg_m_diff: 48.8832 - val_loss: 8.8758e-08 - val_mae: 2.7556e-04 - val_mse: 1.7752e-07 - val_root_mean_squared_error: 4.2133e-04
# Epoch 24/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 55.9807 - loss: 1.3269e-07 - mae: 3.1759e-04 - mse: 2.6538e-07 - root_mean_squared_error: 5.0942e-04 - val_avg_m_diff: 67.5049 - val_loss: 1.4565e-07 - val_mae: 3.9489e-04 - val_mse: 2.9129e-07 - val_root_mean_squared_error: 5.3971e-04
# Epoch 25/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 54.9790 - loss: 1.1601e-07 - mae: 3.1072e-04 - mse: 2.3202e-07 - root_mean_squared_error: 4.7577e-04 - val_avg_m_diff: 49.8240 - val_loss: 9.0709e-08 - val_mae: 2.8164e-04 - val_mse: 1.8142e-07 - val_root_mean_squared_error: 4.2593e-04
# Epoch 26/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 53.6227 - loss: 9.4561e-08 - mae: 3.0322e-04 - mse: 1.8912e-07 - root_mean_squared_error: 4.3403e-04 - val_avg_m_diff: 53.7624 - val_loss: 9.8783e-08 - val_mae: 3.0592e-04 - val_mse: 1.9757e-07 - val_root_mean_squared_error: 4.4448e-04
# Epoch 27/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 56.6079 - loss: 1.1434e-07 - mae: 3.2245e-04 - mse: 2.2869e-07 - root_mean_squared_error: 4.7710e-04 - val_avg_m_diff: 78.5527 - val_loss: 1.9918e-07 - val_mae: 4.5585e-04 - val_mse: 3.9837e-07 - val_root_mean_squared_error: 6.3116e-04
# Epoch 28/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 56.2169 - loss: 1.0873e-07 - mae: 3.2052e-04 - mse: 2.1746e-07 - root_mean_squared_error: 4.6459e-04 - val_avg_m_diff: 56.9121 - val_loss: 1.1254e-07 - val_mae: 3.1977e-04 - val_mse: 2.2508e-07 - val_root_mean_squared_error: 4.7442e-04
# Epoch 29/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 59.5989 - loss: 2.2365e-07 - mae: 3.3958e-04 - mse: 4.4730e-07 - root_mean_squared_error: 6.4490e-04 - val_avg_m_diff: 43.2041 - val_loss: 7.1190e-08 - val_mae: 2.4310e-04 - val_mse: 1.4238e-07 - val_root_mean_squared_error: 3.7733e-04
# Epoch 30/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 49.7593 - loss: 9.1332e-08 - mae: 2.8175e-04 - mse: 1.8266e-07 - root_mean_squared_error: 4.2396e-04 - val_avg_m_diff: 72.1998 - val_loss: 1.8560e-07 - val_mae: 4.2142e-04 - val_mse: 3.7121e-07 - val_root_mean_squared_error: 6.0927e-04
# Epoch 31/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 57.6641 - loss: 1.4485e-07 - mae: 3.2794e-04 - mse: 2.8969e-07 - root_mean_squared_error: 5.3375e-04 - val_avg_m_diff: 46.4850 - val_loss: 7.7844e-08 - val_mae: 2.6245e-04 - val_mse: 1.5569e-07 - val_root_mean_squared_error: 3.9457e-04
# Epoch 32/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 55.6821 - loss: 1.0915e-07 - mae: 3.1675e-04 - mse: 2.1831e-07 - root_mean_squared_error: 4.6593e-04 - val_avg_m_diff: 54.2304 - val_loss: 1.0184e-07 - val_mae: 3.0952e-04 - val_mse: 2.0369e-07 - val_root_mean_squared_error: 4.5132e-04
# Epoch 33/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 55.5687 - loss: 1.2122e-07 - mae: 3.1617e-04 - mse: 2.4243e-07 - root_mean_squared_error: 4.8509e-04 - val_avg_m_diff: 45.5347 - val_loss: 7.6943e-08 - val_mae: 2.5633e-04 - val_mse: 1.5389e-07 - val_root_mean_squared_error: 3.9228e-04
# Epoch 34/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 54.1947 - loss: 1.2506e-07 - mae: 3.0738e-04 - mse: 2.5012e-07 - root_mean_squared_error: 4.9565e-04 - val_avg_m_diff: 52.7445 - val_loss: 8.7841e-08 - val_mae: 3.0238e-04 - val_mse: 1.7568e-07 - val_root_mean_squared_error: 4.1915e-04
# Epoch 35/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - avg_m_diff: 52.3548 - loss: 1.0429e-07 - mae: 2.9724e-04 - mse: 2.0858e-07 - root_mean_squared_error: 4.5366e-04 - val_avg_m_diff: 48.9150 - val_loss: 8.9351e-08 - val_mae: 2.7513e-04 - val_mse: 1.7870e-07 - val_root_mean_squared_error: 4.2273e-04
# Epoch 36/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - avg_m_diff: 54.2673 - loss: 1.1271e-07 - mae: 3.0877e-04 - mse: 2.2543e-07 - root_mean_squared_error: 4.7284e-04 - val_avg_m_diff: 47.0916 - val_loss: 7.9469e-08 - val_mae: 2.6697e-04 - val_mse: 1.5894e-07 - val_root_mean_squared_error: 3.9867e-04
# Epoch 37/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - avg_m_diff: 55.6414 - loss: 1.4134e-07 - mae: 3.1704e-04 - mse: 2.8268e-07 - root_mean_squared_error: 5.2141e-04 - val_avg_m_diff: 72.0599 - val_loss: 1.7980e-07 - val_mae: 4.0747e-04 - val_mse: 3.5960e-07 - val_root_mean_squared_error: 5.9966e-04
# Epoch 38/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 51.7110 - loss: 8.8504e-08 - mae: 2.9245e-04 - mse: 1.7701e-07 - root_mean_squared_error: 4.1985e-04 - val_avg_m_diff: 57.7206 - val_loss: 1.0477e-07 - val_mae: 3.2370e-04 - val_mse: 2.0954e-07 - val_root_mean_squared_error: 4.5776e-04
# Epoch 39/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 56.5187 - loss: 1.1875e-07 - mae: 3.2108e-04 - mse: 2.3750e-07 - root_mean_squared_error: 4.8318e-04 - val_avg_m_diff: 47.9885 - val_loss: 8.6355e-08 - val_mae: 2.7234e-04 - val_mse: 1.7271e-07 - val_root_mean_squared_error: 4.1558e-04
# Epoch 40/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 51.1341 - loss: 1.3619e-07 - mae: 2.8952e-04 - mse: 2.7239e-07 - root_mean_squared_error: 5.1443e-04 - val_avg_m_diff: 51.5836 - val_loss: 9.0142e-08 - val_mae: 2.9091e-04 - val_mse: 1.8028e-07 - val_root_mean_squared_error: 4.2460e-04
# Epoch 41/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 53.0798 - loss: 1.1057e-07 - mae: 3.0188e-04 - mse: 2.2115e-07 - root_mean_squared_error: 4.6903e-04 - val_avg_m_diff: 46.3597 - val_loss: 7.4949e-08 - val_mae: 2.6258e-04 - val_mse: 1.4990e-07 - val_root_mean_squared_error: 3.8717e-04
# Epoch 42/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - avg_m_diff: 50.0023 - loss: 8.4374e-08 - mae: 2.8346e-04 - mse: 1.6875e-07 - root_mean_squared_error: 4.0938e-04 - val_avg_m_diff: 76.6254 - val_loss: 1.9664e-07 - val_mae: 4.2879e-04 - val_mse: 3.9328e-07 - val_root_mean_squared_error: 6.2712e-04
# Epoch 43/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 53.2922 - loss: 9.4695e-08 - mae: 3.0261e-04 - mse: 1.8939e-07 - root_mean_squared_error: 4.3433e-04 - val_avg_m_diff: 45.2364 - val_loss: 7.1541e-08 - val_mae: 2.5624e-04 - val_mse: 1.4308e-07 - val_root_mean_squared_error: 3.7826e-04
# Epoch 44/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - avg_m_diff: 50.6074 - loss: 8.5841e-08 - mae: 2.8771e-04 - mse: 1.7168e-07 - root_mean_squared_error: 4.1367e-04 - val_avg_m_diff: 44.4682 - val_loss: 7.1313e-08 - val_mae: 2.5265e-04 - val_mse: 1.4263e-07 - val_root_mean_squared_error: 3.7766e-04
# Epoch 45/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 51.0576 - loss: 8.6842e-08 - mae: 2.9034e-04 - mse: 1.7368e-07 - root_mean_squared_error: 4.1590e-04 - val_avg_m_diff: 41.0502 - val_loss: 7.0397e-08 - val_mae: 2.2997e-04 - val_mse: 1.4079e-07 - val_root_mean_squared_error: 3.7522e-04
# Epoch 46/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 51.8001 - loss: 1.0146e-07 - mae: 2.9480e-04 - mse: 2.0293e-07 - root_mean_squared_error: 4.4834e-04 - val_avg_m_diff: 51.3710 - val_loss: 8.6945e-08 - val_mae: 2.9248e-04 - val_mse: 1.7389e-07 - val_root_mean_squared_error: 4.1700e-04
# Epoch 47/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 31s 24ms/step - avg_m_diff: 51.9059 - loss: 8.9267e-08 - mae: 2.9538e-04 - mse: 1.7853e-07 - root_mean_squared_error: 4.2212e-04 - val_avg_m_diff: 54.6584 - val_loss: 9.6728e-08 - val_mae: 3.1115e-04 - val_mse: 1.9346e-07 - val_root_mean_squared_error: 4.3984e-04
# Epoch 48/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 30s 24ms/step - avg_m_diff: 50.3398 - loss: 8.2989e-08 - mae: 2.8505e-04 - mse: 1.6598e-07 - root_mean_squared_error: 4.0724e-04 - val_avg_m_diff: 46.4514 - val_loss: 7.6705e-08 - val_mae: 2.6279e-04 - val_mse: 1.5341e-07 - val_root_mean_squared_error: 3.9168e-04
# Epoch 49/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 29s 23ms/step - avg_m_diff: 52.0512 - loss: 1.1692e-07 - mae: 2.9478e-04 - mse: 2.3385e-07 - root_mean_squared_error: 4.7953e-04 - val_avg_m_diff: 46.7149 - val_loss: 7.6026e-08 - val_mae: 2.6297e-04 - val_mse: 1.5205e-07 - val_root_mean_squared_error: 3.8994e-04
# Epoch 50/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 48.8661 - loss: 7.9544e-08 - mae: 2.7732e-04 - mse: 1.5909e-07 - root_mean_squared_error: 3.9821e-04 - val_avg_m_diff: 49.4142 - val_loss: 8.3353e-08 - val_mae: 2.8301e-04 - val_mse: 1.6671e-07 - val_root_mean_squared_error: 4.0830e-04
# Epoch 51/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 51.5300 - loss: 9.2757e-08 - mae: 2.9230e-04 - mse: 1.8551e-07 - root_mean_squared_error: 4.2966e-04 - val_avg_m_diff: 56.7256 - val_loss: 1.1141e-07 - val_mae: 3.1873e-04 - val_mse: 2.2282e-07 - val_root_mean_squared_error: 4.7203e-04
# Epoch 52/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 48.2775 - loss: 7.5776e-08 - mae: 2.7350e-04 - mse: 1.5155e-07 - root_mean_squared_error: 3.8911e-04 - val_avg_m_diff: 44.7333 - val_loss: 7.1048e-08 - val_mae: 2.5229e-04 - val_mse: 1.4210e-07 - val_root_mean_squared_error: 3.7696e-04
# Epoch 53/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 49.0901 - loss: 7.8725e-08 - mae: 2.7861e-04 - mse: 1.5745e-07 - root_mean_squared_error: 3.9632e-04 - val_avg_m_diff: 49.6284 - val_loss: 8.7114e-08 - val_mae: 2.8495e-04 - val_mse: 1.7423e-07 - val_root_mean_squared_error: 4.1741e-04
# Epoch 54/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 49.1756 - loss: 8.2133e-08 - mae: 2.7839e-04 - mse: 1.6427e-07 - root_mean_squared_error: 4.0461e-04 - val_avg_m_diff: 41.1186 - val_loss: 6.2825e-08 - val_mae: 2.3068e-04 - val_mse: 1.2565e-07 - val_root_mean_squared_error: 3.5447e-04
# Epoch 55/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 43s 20ms/step - avg_m_diff: 53.5787 - loss: 1.0382e-07 - mae: 3.0546e-04 - mse: 2.0765e-07 - root_mean_squared_error: 4.5399e-04 - val_avg_m_diff: 68.2562 - val_loss: 1.4905e-07 - val_mae: 4.0194e-04 - val_mse: 2.9811e-07 - val_root_mean_squared_error: 5.4599e-04
# Epoch 56/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 50.4308 - loss: 8.3187e-08 - mae: 2.8656e-04 - mse: 1.6637e-07 - root_mean_squared_error: 4.0776e-04 - val_avg_m_diff: 44.7553 - val_loss: 6.9149e-08 - val_mae: 2.5235e-04 - val_mse: 1.3830e-07 - val_root_mean_squared_error: 3.7188e-04
# Epoch 57/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 49.3386 - loss: 8.4597e-08 - mae: 2.8032e-04 - mse: 1.6919e-07 - root_mean_squared_error: 4.1060e-04 - val_avg_m_diff: 47.6389 - val_loss: 7.7191e-08 - val_mae: 2.7106e-04 - val_mse: 1.5438e-07 - val_root_mean_squared_error: 3.9292e-04
# Epoch 58/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 33s 26ms/step - avg_m_diff: 50.5439 - loss: 9.1116e-08 - mae: 2.8589e-04 - mse: 1.8223e-07 - root_mean_squared_error: 4.2459e-04 - val_avg_m_diff: 53.5952 - val_loss: 9.5076e-08 - val_mae: 3.0168e-04 - val_mse: 1.9015e-07 - val_root_mean_squared_error: 4.3606e-04
# Epoch 59/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 32s 25ms/step - avg_m_diff: 50.3657 - loss: 8.3186e-08 - mae: 2.8595e-04 - mse: 1.6637e-07 - root_mean_squared_error: 4.0743e-04 - val_avg_m_diff: 44.1104 - val_loss: 7.0889e-08 - val_mae: 2.4841e-04 - val_mse: 1.4178e-07 - val_root_mean_squared_error: 3.7653e-04
# Epoch 60/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 48.4041 - loss: 7.4947e-08 - mae: 2.7511e-04 - mse: 1.4989e-07 - root_mean_squared_error: 3.8688e-04 - val_avg_m_diff: 92.8973 - val_loss: 3.5659e-07 - val_mae: 5.3363e-04 - val_mse: 7.1319e-07 - val_root_mean_squared_error: 8.4450e-04
# Epoch 61/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 57.6331 - loss: 1.3047e-07 - mae: 3.2797e-04 - mse: 2.6093e-07 - root_mean_squared_error: 4.9991e-04 - val_avg_m_diff: 68.6214 - val_loss: 1.7214e-07 - val_mae: 3.7531e-04 - val_mse: 3.4427e-07 - val_root_mean_squared_error: 5.8675e-04
# Epoch 62/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 52.6090 - loss: 9.6158e-08 - mae: 2.9745e-04 - mse: 1.9232e-07 - root_mean_squared_error: 4.3412e-04 - val_avg_m_diff: 44.8844 - val_loss: 6.9118e-08 - val_mae: 2.5543e-04 - val_mse: 1.3824e-07 - val_root_mean_squared_error: 3.7180e-04
# Epoch 63/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 51.5887 - loss: 9.1399e-08 - mae: 2.9415e-04 - mse: 1.8280e-07 - root_mean_squared_error: 4.2654e-04 - val_avg_m_diff: 48.5393 - val_loss: 8.0253e-08 - val_mae: 2.7252e-04 - val_mse: 1.6051e-07 - val_root_mean_squared_error: 4.0063e-04
# Epoch 64/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.8857 - loss: 7.2341e-08 - mae: 2.7178e-04 - mse: 1.4468e-07 - root_mean_squared_error: 3.8035e-04 - val_avg_m_diff: 49.1651 - val_loss: 8.1446e-08 - val_mae: 2.8243e-04 - val_mse: 1.6289e-07 - val_root_mean_squared_error: 4.0360e-04
# Epoch 65/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 46.8836 - loss: 7.1390e-08 - mae: 2.6575e-04 - mse: 1.4278e-07 - root_mean_squared_error: 3.7716e-04 - val_avg_m_diff: 45.3735 - val_loss: 7.0317e-08 - val_mae: 2.5634e-04 - val_mse: 1.4063e-07 - val_root_mean_squared_error: 3.7501e-04
# Epoch 66/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.9151 - loss: 7.0191e-08 - mae: 2.6618e-04 - mse: 1.4038e-07 - root_mean_squared_error: 3.7452e-04 - val_avg_m_diff: 49.4679 - val_loss: 8.2173e-08 - val_mae: 2.8176e-04 - val_mse: 1.6435e-07 - val_root_mean_squared_error: 4.0540e-04
# Epoch 67/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - avg_m_diff: 48.1500 - loss: 7.4035e-08 - mae: 2.7359e-04 - mse: 1.4807e-07 - root_mean_squared_error: 3.8471e-04 - val_avg_m_diff: 48.7121 - val_loss: 7.5030e-08 - val_mae: 2.7983e-04 - val_mse: 1.5006e-07 - val_root_mean_squared_error: 3.8737e-04
# Epoch 68/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - avg_m_diff: 46.9706 - loss: 7.0282e-08 - mae: 2.6626e-04 - mse: 1.4056e-07 - root_mean_squared_error: 3.7478e-04 - val_avg_m_diff: 60.9949 - val_loss: 1.2034e-07 - val_mae: 3.4186e-04 - val_mse: 2.4067e-07 - val_root_mean_squared_error: 4.9058e-04
# Epoch 69/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.6399 - loss: 7.1772e-08 - mae: 2.7029e-04 - mse: 1.4354e-07 - root_mean_squared_error: 3.7866e-04 - val_avg_m_diff: 50.4676 - val_loss: 8.6167e-08 - val_mae: 2.8542e-04 - val_mse: 1.7233e-07 - val_root_mean_squared_error: 4.1513e-04
# Epoch 70/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 51.6682 - loss: 9.1833e-08 - mae: 2.9226e-04 - mse: 1.8367e-07 - root_mean_squared_error: 4.2740e-04 - val_avg_m_diff: 39.2913 - val_loss: 5.8734e-08 - val_mae: 2.2099e-04 - val_mse: 1.1747e-07 - val_root_mean_squared_error: 3.4274e-04
# Epoch 71/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.8227 - loss: 7.1062e-08 - mae: 2.6596e-04 - mse: 1.4212e-07 - root_mean_squared_error: 3.7659e-04 - val_avg_m_diff: 46.3711 - val_loss: 7.3033e-08 - val_mae: 2.6263e-04 - val_mse: 1.4607e-07 - val_root_mean_squared_error: 3.8218e-04
# Epoch 72/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.9131 - loss: 7.0444e-08 - mae: 2.6663e-04 - mse: 1.4089e-07 - root_mean_squared_error: 3.7521e-04 - val_avg_m_diff: 50.1623 - val_loss: 8.9406e-08 - val_mae: 2.8007e-04 - val_mse: 1.7881e-07 - val_root_mean_squared_error: 4.2286e-04
# Epoch 73/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 48.6478 - loss: 7.6807e-08 - mae: 2.7601e-04 - mse: 1.5361e-07 - root_mean_squared_error: 3.9180e-04 - val_avg_m_diff: 45.9737 - val_loss: 7.3467e-08 - val_mae: 2.6419e-04 - val_mse: 1.4693e-07 - val_root_mean_squared_error: 3.8332e-04
# Epoch 74/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.0128 - loss: 7.1192e-08 - mae: 2.6714e-04 - mse: 1.4238e-07 - root_mean_squared_error: 3.7730e-04 - val_avg_m_diff: 51.1383 - val_loss: 9.3048e-08 - val_mae: 2.9405e-04 - val_mse: 1.8610e-07 - val_root_mean_squared_error: 4.3139e-04
# Epoch 75/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 48.3264 - loss: 7.5889e-08 - mae: 2.7332e-04 - mse: 1.5178e-07 - root_mean_squared_error: 3.8902e-04 - val_avg_m_diff: 41.2009 - val_loss: 6.2655e-08 - val_mae: 2.3062e-04 - val_mse: 1.2531e-07 - val_root_mean_squared_error: 3.5399e-04
# Epoch 76/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.7152 - loss: 7.4659e-08 - mae: 2.7041e-04 - mse: 1.4932e-07 - root_mean_squared_error: 3.8607e-04 - val_avg_m_diff: 53.4518 - val_loss: 1.0034e-07 - val_mae: 2.9629e-04 - val_mse: 2.0068e-07 - val_root_mean_squared_error: 4.4797e-04
# Epoch 77/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.4275 - loss: 7.3001e-08 - mae: 2.6911e-04 - mse: 1.4600e-07 - root_mean_squared_error: 3.8198e-04 - val_avg_m_diff: 49.2089 - val_loss: 8.1513e-08 - val_mae: 2.7917e-04 - val_mse: 1.6303e-07 - val_root_mean_squared_error: 4.0376e-04
# Epoch 78/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.5158 - loss: 6.5808e-08 - mae: 2.5806e-04 - mse: 1.3162e-07 - root_mean_squared_error: 3.6266e-04 - val_avg_m_diff: 55.6274 - val_loss: 1.0300e-07 - val_mae: 3.1596e-04 - val_mse: 2.0601e-07 - val_root_mean_squared_error: 4.5388e-04
# Epoch 79/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 48.7598 - loss: 7.6431e-08 - mae: 2.7766e-04 - mse: 1.5286e-07 - root_mean_squared_error: 3.9065e-04 - val_avg_m_diff: 40.6267 - val_loss: 6.2679e-08 - val_mae: 2.2881e-04 - val_mse: 1.2536e-07 - val_root_mean_squared_error: 3.5406e-04
# Epoch 80/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 48.7824 - loss: 7.7366e-08 - mae: 2.7746e-04 - mse: 1.5473e-07 - root_mean_squared_error: 3.9280e-04 - val_avg_m_diff: 45.7677 - val_loss: 7.1937e-08 - val_mae: 2.5857e-04 - val_mse: 1.4387e-07 - val_root_mean_squared_error: 3.7931e-04
# Epoch 81/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.9582 - loss: 6.9693e-08 - mae: 2.6684e-04 - mse: 1.3939e-07 - root_mean_squared_error: 3.7328e-04 - val_avg_m_diff: 39.5075 - val_loss: 5.7879e-08 - val_mae: 2.2185e-04 - val_mse: 1.1576e-07 - val_root_mean_squared_error: 3.4023e-04
# Epoch 82/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.6057 - loss: 6.9166e-08 - mae: 2.6377e-04 - mse: 1.3833e-07 - root_mean_squared_error: 3.7185e-04 - val_avg_m_diff: 47.3088 - val_loss: 7.7371e-08 - val_mae: 2.6806e-04 - val_mse: 1.5474e-07 - val_root_mean_squared_error: 3.9337e-04
# Epoch 83/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 45.0183 - loss: 6.4174e-08 - mae: 2.5510e-04 - mse: 1.2835e-07 - root_mean_squared_error: 3.5817e-04 - val_avg_m_diff: 49.0685 - val_loss: 7.9728e-08 - val_mae: 2.7886e-04 - val_mse: 1.5946e-07 - val_root_mean_squared_error: 3.9932e-04
# Epoch 84/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.0859 - loss: 6.8003e-08 - mae: 2.6132e-04 - mse: 1.3601e-07 - root_mean_squared_error: 3.6876e-04 - val_avg_m_diff: 42.2443 - val_loss: 6.4699e-08 - val_mae: 2.3948e-04 - val_mse: 1.2940e-07 - val_root_mean_squared_error: 3.5972e-04
# Epoch 85/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.7958 - loss: 6.6973e-08 - mae: 2.5971e-04 - mse: 1.3395e-07 - root_mean_squared_error: 3.6595e-04 - val_avg_m_diff: 47.1805 - val_loss: 7.4444e-08 - val_mae: 2.6744e-04 - val_mse: 1.4889e-07 - val_root_mean_squared_error: 3.8586e-04
# Epoch 86/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 46.5848 - loss: 7.0338e-08 - mae: 2.6542e-04 - mse: 1.4068e-07 - root_mean_squared_error: 3.7407e-04 - val_avg_m_diff: 58.9809 - val_loss: 1.0922e-07 - val_mae: 3.3238e-04 - val_mse: 2.1844e-07 - val_root_mean_squared_error: 4.6738e-04
# Epoch 87/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.2425 - loss: 6.8396e-08 - mae: 2.6256e-04 - mse: 1.3679e-07 - root_mean_squared_error: 3.6970e-04 - val_avg_m_diff: 52.7908 - val_loss: 9.2020e-08 - val_mae: 3.0348e-04 - val_mse: 1.8404e-07 - val_root_mean_squared_error: 4.2900e-04
# Epoch 88/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.3354 - loss: 6.7858e-08 - mae: 2.6351e-04 - mse: 1.3572e-07 - root_mean_squared_error: 3.6836e-04 - val_avg_m_diff: 44.1093 - val_loss: 7.0867e-08 - val_mae: 2.5016e-04 - val_mse: 1.4173e-07 - val_root_mean_squared_error: 3.7648e-04
# Epoch 89/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.8532 - loss: 7.3339e-08 - mae: 2.7233e-04 - mse: 1.4668e-07 - root_mean_squared_error: 3.8277e-04 - val_avg_m_diff: 44.1925 - val_loss: 6.9056e-08 - val_mae: 2.5056e-04 - val_mse: 1.3811e-07 - val_root_mean_squared_error: 3.7163e-04
# Epoch 90/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.9461 - loss: 6.6668e-08 - mae: 2.6054e-04 - mse: 1.3334e-07 - root_mean_squared_error: 3.6504e-04 - val_avg_m_diff: 47.9865 - val_loss: 7.7660e-08 - val_mae: 2.7295e-04 - val_mse: 1.5532e-07 - val_root_mean_squared_error: 3.9411e-04
# Epoch 91/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.1905 - loss: 7.4408e-08 - mae: 2.6859e-04 - mse: 1.4882e-07 - root_mean_squared_error: 3.8498e-04 - val_avg_m_diff: 39.4891 - val_loss: 5.7717e-08 - val_mae: 2.2190e-04 - val_mse: 1.1543e-07 - val_root_mean_squared_error: 3.3976e-04
# Epoch 92/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 46.1342 - loss: 6.8028e-08 - mae: 2.6197e-04 - mse: 1.3606e-07 - root_mean_squared_error: 3.6876e-04 - val_avg_m_diff: 41.6335 - val_loss: 6.1554e-08 - val_mae: 2.3463e-04 - val_mse: 1.2311e-07 - val_root_mean_squared_error: 3.5087e-04
# Epoch 93/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 46.1765 - loss: 6.8268e-08 - mae: 2.6228e-04 - mse: 1.3654e-07 - root_mean_squared_error: 3.6945e-04 - val_avg_m_diff: 42.1988 - val_loss: 6.7185e-08 - val_mae: 2.3635e-04 - val_mse: 1.3437e-07 - val_root_mean_squared_error: 3.6657e-04
# Epoch 94/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 47.1230 - loss: 7.6990e-08 - mae: 2.6724e-04 - mse: 1.5398e-07 - root_mean_squared_error: 3.9134e-04 - val_avg_m_diff: 47.2852 - val_loss: 7.6861e-08 - val_mae: 2.7009e-04 - val_mse: 1.5372e-07 - val_root_mean_squared_error: 3.9207e-04
# Epoch 95/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 45.1407 - loss: 6.5174e-08 - mae: 2.5567e-04 - mse: 1.3035e-07 - root_mean_squared_error: 3.6099e-04 - val_avg_m_diff: 49.7924 - val_loss: 8.8463e-08 - val_mae: 2.8552e-04 - val_mse: 1.7693e-07 - val_root_mean_squared_error: 4.2063e-04
# Epoch 96/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.9207 - loss: 6.4943e-08 - mae: 2.5466e-04 - mse: 1.2989e-07 - root_mean_squared_error: 3.6033e-04 - val_avg_m_diff: 44.0551 - val_loss: 6.6360e-08 - val_mae: 2.5154e-04 - val_mse: 1.3272e-07 - val_root_mean_squared_error: 3.6431e-04
# Epoch 97/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 45.1185 - loss: 6.5227e-08 - mae: 2.5572e-04 - mse: 1.3045e-07 - root_mean_squared_error: 3.6102e-04 - val_avg_m_diff: 42.5814 - val_loss: 6.5313e-08 - val_mae: 2.4035e-04 - val_mse: 1.3063e-07 - val_root_mean_squared_error: 3.6142e-04
# Epoch 98/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - avg_m_diff: 45.9277 - loss: 6.8720e-08 - mae: 2.6030e-04 - mse: 1.3744e-07 - root_mean_squared_error: 3.7054e-04 - val_avg_m_diff: 44.3721 - val_loss: 6.9092e-08 - val_mae: 2.4977e-04 - val_mse: 1.3818e-07 - val_root_mean_squared_error: 3.7173e-04
# Epoch 99/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - avg_m_diff: 44.2741 - loss: 6.2002e-08 - mae: 2.5108e-04 - mse: 1.2400e-07 - root_mean_squared_error: 3.5206e-04 - val_avg_m_diff: 40.9261 - val_loss: 6.0146e-08 - val_mae: 2.3085e-04 - val_mse: 1.2029e-07 - val_root_mean_squared_error: 3.4683e-04
# Epoch 100/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - avg_m_diff: 44.2406 - loss: 6.2924e-08 - mae: 2.5106e-04 - mse: 1.2585e-07 - root_mean_squared_error: 3.5464e-04 - val_avg_m_diff: 44.1915 - val_loss: 6.6500e-08 - val_mae: 2.5022e-04 - val_mse: 1.3300e-07 - val_root_mean_squared_error: 3.6469e-04
# Epoch 101/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 45.2527 - loss: 6.6091e-08 - mae: 2.5684e-04 - mse: 1.3218e-07 - root_mean_squared_error: 3.6343e-04 - val_avg_m_diff: 44.7244 - val_loss: 6.5070e-08 - val_mae: 2.5420e-04 - val_mse: 1.3014e-07 - val_root_mean_squared_error: 3.6075e-04
# Epoch 102/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - avg_m_diff: 43.7040 - loss: 6.0727e-08 - mae: 2.4753e-04 - mse: 1.2145e-07 - root_mean_squared_error: 3.4847e-04 - val_avg_m_diff: 47.8720 - val_loss: 7.5936e-08 - val_mae: 2.7456e-04 - val_mse: 1.5187e-07 - val_root_mean_squared_error: 3.8971e-04
# Epoch 103/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - avg_m_diff: 44.8700 - loss: 6.4852e-08 - mae: 2.5451e-04 - mse: 1.2970e-07 - root_mean_squared_error: 3.6010e-04 - val_avg_m_diff: 47.6521 - val_loss: 7.6456e-08 - val_mae: 2.7272e-04 - val_mse: 1.5291e-07 - val_root_mean_squared_error: 3.9104e-04
# Epoch 104/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 46.3531 - loss: 6.9077e-08 - mae: 2.6306e-04 - mse: 1.3815e-07 - root_mean_squared_error: 3.7149e-04 - val_avg_m_diff: 41.4931 - val_loss: 6.0876e-08 - val_mae: 2.3584e-04 - val_mse: 1.2175e-07 - val_root_mean_squared_error: 3.4893e-04
# Epoch 105/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.4016 - loss: 6.3435e-08 - mae: 2.5175e-04 - mse: 1.2687e-07 - root_mean_squared_error: 3.5610e-04 - val_avg_m_diff: 41.8157 - val_loss: 6.2464e-08 - val_mae: 2.3579e-04 - val_mse: 1.2493e-07 - val_root_mean_squared_error: 3.5345e-04
# Epoch 106/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.4161 - loss: 6.0449e-08 - mae: 2.4586e-04 - mse: 1.2090e-07 - root_mean_squared_error: 3.4760e-04 - val_avg_m_diff: 48.4683 - val_loss: 7.9582e-08 - val_mae: 2.7645e-04 - val_mse: 1.5916e-07 - val_root_mean_squared_error: 3.9895e-04
# Epoch 107/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.0859 - loss: 6.5161e-08 - mae: 2.5604e-04 - mse: 1.3032e-07 - root_mean_squared_error: 3.6095e-04 - val_avg_m_diff: 59.4389 - val_loss: 1.1042e-07 - val_mae: 3.4727e-04 - val_mse: 2.2083e-07 - val_root_mean_squared_error: 4.6993e-04
# Epoch 108/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.1780 - loss: 6.8582e-08 - mae: 2.6304e-04 - mse: 1.3716e-07 - root_mean_squared_error: 3.7000e-04 - val_avg_m_diff: 51.7934 - val_loss: 8.2840e-08 - val_mae: 2.9397e-04 - val_mse: 1.6568e-07 - val_root_mean_squared_error: 4.0704e-04
# Epoch 109/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.9824 - loss: 6.8379e-08 - mae: 2.6082e-04 - mse: 1.3676e-07 - root_mean_squared_error: 3.6967e-04 - val_avg_m_diff: 48.3320 - val_loss: 8.0511e-08 - val_mae: 2.7789e-04 - val_mse: 1.6102e-07 - val_root_mean_squared_error: 4.0128e-04
# Epoch 110/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.5818 - loss: 6.6600e-08 - mae: 2.5836e-04 - mse: 1.3320e-07 - root_mean_squared_error: 3.6485e-04 - val_avg_m_diff: 44.4334 - val_loss: 6.9066e-08 - val_mae: 2.5063e-04 - val_mse: 1.3813e-07 - val_root_mean_squared_error: 3.7166e-04
# Epoch 111/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.5068 - loss: 7.2500e-08 - mae: 2.6387e-04 - mse: 1.4500e-07 - root_mean_squared_error: 3.7886e-04 - val_avg_m_diff: 40.4460 - val_loss: 5.9402e-08 - val_mae: 2.2740e-04 - val_mse: 1.1880e-07 - val_root_mean_squared_error: 3.4468e-04
# Epoch 112/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 46.5074 - loss: 7.1214e-08 - mae: 2.6381e-04 - mse: 1.4243e-07 - root_mean_squared_error: 3.7711e-04 - val_avg_m_diff: 43.6807 - val_loss: 6.7933e-08 - val_mae: 2.4887e-04 - val_mse: 1.3587e-07 - val_root_mean_squared_error: 3.6860e-04
# Epoch 113/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.1457 - loss: 6.0204e-08 - mae: 2.4458e-04 - mse: 1.2041e-07 - root_mean_squared_error: 3.4694e-04 - val_avg_m_diff: 42.6042 - val_loss: 6.5997e-08 - val_mae: 2.4152e-04 - val_mse: 1.3199e-07 - val_root_mean_squared_error: 3.6331e-04
# Epoch 114/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 43.8027 - loss: 6.1875e-08 - mae: 2.4849e-04 - mse: 1.2375e-07 - root_mean_squared_error: 3.5167e-04 - val_avg_m_diff: 56.0914 - val_loss: 1.0736e-07 - val_mae: 3.1642e-04 - val_mse: 2.1471e-07 - val_root_mean_squared_error: 4.6337e-04
# Epoch 115/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.6646 - loss: 6.2188e-08 - mae: 2.4702e-04 - mse: 1.2438e-07 - root_mean_squared_error: 3.5252e-04 - val_avg_m_diff: 51.4531 - val_loss: 8.9536e-08 - val_mae: 2.8992e-04 - val_mse: 1.7907e-07 - val_root_mean_squared_error: 4.2317e-04
# Epoch 116/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 45.0168 - loss: 6.5125e-08 - mae: 2.5601e-04 - mse: 1.3025e-07 - root_mean_squared_error: 3.6075e-04 - val_avg_m_diff: 45.8870 - val_loss: 7.4795e-08 - val_mae: 2.6110e-04 - val_mse: 1.4959e-07 - val_root_mean_squared_error: 3.8677e-04
# Epoch 117/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 45.7386 - loss: 7.3179e-08 - mae: 2.5927e-04 - mse: 1.4636e-07 - root_mean_squared_error: 3.8155e-04 - val_avg_m_diff: 43.4336 - val_loss: 6.7383e-08 - val_mae: 2.4725e-04 - val_mse: 1.3477e-07 - val_root_mean_squared_error: 3.6711e-04
# Epoch 118/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 42.3681 - loss: 5.8379e-08 - mae: 2.4013e-04 - mse: 1.1676e-07 - root_mean_squared_error: 3.4168e-04 - val_avg_m_diff: 50.7591 - val_loss: 8.7769e-08 - val_mae: 2.8957e-04 - val_mse: 1.7554e-07 - val_root_mean_squared_error: 4.1897e-04
# Epoch 119/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.6586 - loss: 6.1590e-08 - mae: 2.4755e-04 - mse: 1.2318e-07 - root_mean_squared_error: 3.5089e-04 - val_avg_m_diff: 55.0030 - val_loss: 9.4568e-08 - val_mae: 3.0952e-04 - val_mse: 1.8914e-07 - val_root_mean_squared_error: 4.3490e-04
# Epoch 120/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.4527 - loss: 6.4094e-08 - mae: 2.5263e-04 - mse: 1.2819e-07 - root_mean_squared_error: 3.5790e-04 - val_avg_m_diff: 39.0183 - val_loss: 5.7094e-08 - val_mae: 2.2088e-04 - val_mse: 1.1419e-07 - val_root_mean_squared_error: 3.3792e-04
# Epoch 121/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.2176 - loss: 6.4405e-08 - mae: 2.5074e-04 - mse: 1.2881e-07 - root_mean_squared_error: 3.5875e-04 - val_avg_m_diff: 42.1862 - val_loss: 6.1974e-08 - val_mae: 2.4016e-04 - val_mse: 1.2395e-07 - val_root_mean_squared_error: 3.5206e-04
# Epoch 122/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 44.1483 - loss: 6.2696e-08 - mae: 2.5037e-04 - mse: 1.2539e-07 - root_mean_squared_error: 3.5408e-04 - val_avg_m_diff: 59.3031 - val_loss: 1.2286e-07 - val_mae: 3.3756e-04 - val_mse: 2.4573e-07 - val_root_mean_squared_error: 4.9571e-04
# Epoch 123/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.0226 - loss: 6.2966e-08 - mae: 2.4990e-04 - mse: 1.2593e-07 - root_mean_squared_error: 3.5452e-04 - val_avg_m_diff: 42.0246 - val_loss: 6.2665e-08 - val_mae: 2.3762e-04 - val_mse: 1.2533e-07 - val_root_mean_squared_error: 3.5402e-04
# Epoch 124/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 44.0494 - loss: 6.2630e-08 - mae: 2.4992e-04 - mse: 1.2526e-07 - root_mean_squared_error: 3.5376e-04 - val_avg_m_diff: 52.4937 - val_loss: 9.4786e-08 - val_mae: 3.0314e-04 - val_mse: 1.8957e-07 - val_root_mean_squared_error: 4.3540e-04
# Epoch 125/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 44.3870 - loss: 6.3863e-08 - mae: 2.5194e-04 - mse: 1.2773e-07 - root_mean_squared_error: 3.5735e-04 - val_avg_m_diff: 42.1545 - val_loss: 6.3758e-08 - val_mae: 2.3963e-04 - val_mse: 1.2752e-07 - val_root_mean_squared_error: 3.5709e-04
# Epoch 126/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 43.1474 - loss: 5.9556e-08 - mae: 2.4512e-04 - mse: 1.1911e-07 - root_mean_squared_error: 3.4510e-04 - val_avg_m_diff: 43.8462 - val_loss: 6.8164e-08 - val_mae: 2.4661e-04 - val_mse: 1.3633e-07 - val_root_mean_squared_error: 3.6923e-04
# Epoch 127/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 43.5812 - loss: 6.1299e-08 - mae: 2.4736e-04 - mse: 1.2260e-07 - root_mean_squared_error: 3.5004e-04 - val_avg_m_diff: 42.4926 - val_loss: 6.4567e-08 - val_mae: 2.4081e-04 - val_mse: 1.2913e-07 - val_root_mean_squared_error: 3.5935e-04
# Epoch 128/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.6896 - loss: 6.5632e-08 - mae: 2.5433e-04 - mse: 1.3126e-07 - root_mean_squared_error: 3.6206e-04 - val_avg_m_diff: 41.8626 - val_loss: 6.3429e-08 - val_mae: 2.3846e-04 - val_mse: 1.2686e-07 - val_root_mean_squared_error: 3.5617e-04
# Epoch 129/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 43.6815 - loss: 6.1785e-08 - mae: 2.4776e-04 - mse: 1.2357e-07 - root_mean_squared_error: 3.5140e-04 - val_avg_m_diff: 41.3347 - val_loss: 5.9669e-08 - val_mae: 2.3512e-04 - val_mse: 1.1934e-07 - val_root_mean_squared_error: 3.4545e-04
# Epoch 130/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.4718 - loss: 6.0920e-08 - mae: 2.4681e-04 - mse: 1.2184e-07 - root_mean_squared_error: 3.4900e-04 - val_avg_m_diff: 39.1435 - val_loss: 5.9718e-08 - val_mae: 2.2205e-04 - val_mse: 1.1944e-07 - val_root_mean_squared_error: 3.4559e-04
# Epoch 131/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.4211 - loss: 6.7967e-08 - mae: 2.5792e-04 - mse: 1.3593e-07 - root_mean_squared_error: 3.6851e-04 - val_avg_m_diff: 44.8077 - val_loss: 6.6638e-08 - val_mae: 2.5574e-04 - val_mse: 1.3328e-07 - val_root_mean_squared_error: 3.6507e-04
# Epoch 132/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 44.3775 - loss: 6.4046e-08 - mae: 2.5196e-04 - mse: 1.2809e-07 - root_mean_squared_error: 3.5784e-04 - val_avg_m_diff: 39.7827 - val_loss: 5.6519e-08 - val_mae: 2.2639e-04 - val_mse: 1.1304e-07 - val_root_mean_squared_error: 3.3621e-04
# Epoch 133/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 42.6340 - loss: 5.8360e-08 - mae: 2.4153e-04 - mse: 1.1672e-07 - root_mean_squared_error: 3.4158e-04 - val_avg_m_diff: 46.1497 - val_loss: 7.3052e-08 - val_mae: 2.6581e-04 - val_mse: 1.4610e-07 - val_root_mean_squared_error: 3.8224e-04
# Epoch 134/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.8256 - loss: 6.1330e-08 - mae: 2.4920e-04 - mse: 1.2266e-07 - root_mean_squared_error: 3.5016e-04 - val_avg_m_diff: 61.3341 - val_loss: 1.3056e-07 - val_mae: 3.4382e-04 - val_mse: 2.6113e-07 - val_root_mean_squared_error: 5.1101e-04
# Epoch 135/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.9352 - loss: 6.1812e-08 - mae: 2.4941e-04 - mse: 1.2362e-07 - root_mean_squared_error: 3.5145e-04 - val_avg_m_diff: 40.6682 - val_loss: 6.0703e-08 - val_mae: 2.3173e-04 - val_mse: 1.2141e-07 - val_root_mean_squared_error: 3.4843e-04
# Epoch 136/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.1722 - loss: 6.0329e-08 - mae: 2.4530e-04 - mse: 1.2066e-07 - root_mean_squared_error: 3.4729e-04 - val_avg_m_diff: 48.5453 - val_loss: 8.1391e-08 - val_mae: 2.7204e-04 - val_mse: 1.6278e-07 - val_root_mean_squared_error: 4.0346e-04
# Epoch 137/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 44.3312 - loss: 6.4850e-08 - mae: 2.5146e-04 - mse: 1.2970e-07 - root_mean_squared_error: 3.5982e-04 - val_avg_m_diff: 43.8232 - val_loss: 6.4018e-08 - val_mae: 2.4975e-04 - val_mse: 1.2804e-07 - val_root_mean_squared_error: 3.5782e-04
# Epoch 138/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 44.0657 - loss: 6.3035e-08 - mae: 2.5019e-04 - mse: 1.2607e-07 - root_mean_squared_error: 3.5490e-04 - val_avg_m_diff: 41.8794 - val_loss: 6.2434e-08 - val_mae: 2.3660e-04 - val_mse: 1.2487e-07 - val_root_mean_squared_error: 3.5337e-04
# Epoch 139/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 43.0637 - loss: 6.0418e-08 - mae: 2.4453e-04 - mse: 1.2084e-07 - root_mean_squared_error: 3.4756e-04 - val_avg_m_diff: 39.9995 - val_loss: 5.7674e-08 - val_mae: 2.2632e-04 - val_mse: 1.1535e-07 - val_root_mean_squared_error: 3.3963e-04
# Epoch 140/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 41.6640 - loss: 5.6555e-08 - mae: 2.3640e-04 - mse: 1.1311e-07 - root_mean_squared_error: 3.3626e-04 - val_avg_m_diff: 40.3772 - val_loss: 5.9532e-08 - val_mae: 2.2912e-04 - val_mse: 1.1906e-07 - val_root_mean_squared_error: 3.4506e-04
# Epoch 141/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - avg_m_diff: 43.5924 - loss: 6.2519e-08 - mae: 2.4736e-04 - mse: 1.2504e-07 - root_mean_squared_error: 3.5343e-04 - val_avg_m_diff: 44.2855 - val_loss: 6.9141e-08 - val_mae: 2.5073e-04 - val_mse: 1.3828e-07 - val_root_mean_squared_error: 3.7186e-04
# Epoch 142/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.7009 - loss: 6.1616e-08 - mae: 2.4837e-04 - mse: 1.2323e-07 - root_mean_squared_error: 3.5095e-04 - val_avg_m_diff: 36.7176 - val_loss: 5.0803e-08 - val_mae: 2.0668e-04 - val_mse: 1.0161e-07 - val_root_mean_squared_error: 3.1876e-04
# Epoch 143/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 41.7875 - loss: 5.7125e-08 - mae: 2.3659e-04 - mse: 1.1425e-07 - root_mean_squared_error: 3.3794e-04 - val_avg_m_diff: 39.1425 - val_loss: 5.5410e-08 - val_mae: 2.2283e-04 - val_mse: 1.1082e-07 - val_root_mean_squared_error: 3.3290e-04
# Epoch 144/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 43.2638 - loss: 6.1441e-08 - mae: 2.4597e-04 - mse: 1.2288e-07 - root_mean_squared_error: 3.5037e-04 - val_avg_m_diff: 41.2770 - val_loss: 6.4507e-08 - val_mae: 2.3502e-04 - val_mse: 1.2901e-07 - val_root_mean_squared_error: 3.5919e-04
# Epoch 145/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - avg_m_diff: 42.6119 - loss: 5.9112e-08 - mae: 2.4143e-04 - mse: 1.1822e-07 - root_mean_squared_error: 3.4368e-04 - val_avg_m_diff: 44.5432 - val_loss: 7.1910e-08 - val_mae: 2.5282e-04 - val_mse: 1.4382e-07 - val_root_mean_squared_error: 3.7924e-04
# Epoch 146/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 41.8007 - loss: 5.7153e-08 - mae: 2.3705e-04 - mse: 1.1431e-07 - root_mean_squared_error: 3.3806e-04 - val_avg_m_diff: 70.5172 - val_loss: 1.9613e-07 - val_mae: 3.9239e-04 - val_mse: 3.9225e-07 - val_root_mean_squared_error: 6.2630e-04
# Epoch 147/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 45.0308 - loss: 6.8543e-08 - mae: 2.5566e-04 - mse: 1.3709e-07 - root_mean_squared_error: 3.6820e-04 - val_avg_m_diff: 47.8103 - val_loss: 7.7534e-08 - val_mae: 2.7012e-04 - val_mse: 1.5507e-07 - val_root_mean_squared_error: 3.9379e-04
# Epoch 148/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.3363 - loss: 6.0910e-08 - mae: 2.4645e-04 - mse: 1.2182e-07 - root_mean_squared_error: 3.4900e-04 - val_avg_m_diff: 41.0497 - val_loss: 6.2670e-08 - val_mae: 2.3324e-04 - val_mse: 1.2534e-07 - val_root_mean_squared_error: 3.5403e-04
# Epoch 149/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 42.5860 - loss: 5.9414e-08 - mae: 2.4184e-04 - mse: 1.1883e-07 - root_mean_squared_error: 3.4465e-04 - val_avg_m_diff: 48.5140 - val_loss: 8.7786e-08 - val_mae: 2.8045e-04 - val_mse: 1.7557e-07 - val_root_mean_squared_error: 4.1901e-04
# Epoch 150/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 42.6258 - loss: 5.9521e-08 - mae: 2.4168e-04 - mse: 1.1904e-07 - root_mean_squared_error: 3.4483e-04 - val_avg_m_diff: 37.0628 - val_loss: 5.1594e-08 - val_mae: 2.0976e-04 - val_mse: 1.0319e-07 - val_root_mean_squared_error: 3.2123e-04
# Epoch 151/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 42.3383 - loss: 5.8957e-08 - mae: 2.4031e-04 - mse: 1.1791e-07 - root_mean_squared_error: 3.4328e-04 - val_avg_m_diff: 45.4966 - val_loss: 7.4266e-08 - val_mae: 2.6280e-04 - val_mse: 1.4853e-07 - val_root_mean_squared_error: 3.8540e-04
# Epoch 152/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 43.9063 - loss: 6.3309e-08 - mae: 2.4939e-04 - mse: 1.2662e-07 - root_mean_squared_error: 3.5566e-04 - val_avg_m_diff: 37.3648 - val_loss: 5.1395e-08 - val_mae: 2.1041e-04 - val_mse: 1.0279e-07 - val_root_mean_squared_error: 3.2061e-04
# Epoch 153/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 42.5235 - loss: 5.8841e-08 - mae: 2.4157e-04 - mse: 1.1768e-07 - root_mean_squared_error: 3.4293e-04 - val_avg_m_diff: 46.0109 - val_loss: 6.8000e-08 - val_mae: 2.6049e-04 - val_mse: 1.3600e-07 - val_root_mean_squared_error: 3.6878e-04
# Epoch 154/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 41.9271 - loss: 5.7567e-08 - mae: 2.3781e-04 - mse: 1.1513e-07 - root_mean_squared_error: 3.3927e-04 - val_avg_m_diff: 39.4964 - val_loss: 5.7258e-08 - val_mae: 2.2524e-04 - val_mse: 1.1452e-07 - val_root_mean_squared_error: 3.3840e-04
# Epoch 155/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 43.5945 - loss: 6.4343e-08 - mae: 2.4745e-04 - mse: 1.2869e-07 - root_mean_squared_error: 3.5849e-04 - val_avg_m_diff: 42.1982 - val_loss: 6.3180e-08 - val_mae: 2.4075e-04 - val_mse: 1.2636e-07 - val_root_mean_squared_error: 3.5547e-04
# Epoch 156/1000
# ...
# Epoch 951/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.2301 - loss: 2.0044e-08 - mae: 1.2732e-04 - mse: 4.0087e-08 - root_mean_squared_error: 2.0018e-04 - val_avg_m_diff: 23.5050 - val_loss: 2.7088e-08 - val_mae: 1.3617e-04 - val_mse: 5.4176e-08 - val_root_mean_squared_error: 2.3276e-04
# Epoch 952/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.5074 - loss: 2.0589e-08 - mae: 1.2871e-04 - mse: 4.1178e-08 - root_mean_squared_error: 2.0284e-04 - val_avg_m_diff: 20.7031 - val_loss: 2.3619e-08 - val_mae: 1.1915e-04 - val_mse: 4.7238e-08 - val_root_mean_squared_error: 2.1734e-04
# Epoch 953/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.3300 - loss: 2.0755e-08 - mae: 1.2806e-04 - mse: 4.1511e-08 - root_mean_squared_error: 2.0368e-04 - val_avg_m_diff: 27.8534 - val_loss: 2.9682e-08 - val_mae: 1.5750e-04 - val_mse: 5.9364e-08 - val_root_mean_squared_error: 2.4365e-04
# Epoch 954/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.6785 - loss: 2.0640e-08 - mae: 1.2994e-04 - mse: 4.1280e-08 - root_mean_squared_error: 2.0314e-04 - val_avg_m_diff: 20.5340 - val_loss: 2.3876e-08 - val_mae: 1.1781e-04 - val_mse: 4.7753e-08 - val_root_mean_squared_error: 2.1852e-04
# Epoch 955/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.5207 - loss: 1.8820e-08 - mae: 1.2340e-04 - mse: 3.7641e-08 - root_mean_squared_error: 1.9397e-04 - val_avg_m_diff: 23.2139 - val_loss: 2.5828e-08 - val_mae: 1.3223e-04 - val_mse: 5.1657e-08 - val_root_mean_squared_error: 2.2728e-04
# Epoch 956/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.1943 - loss: 1.9665e-08 - mae: 1.2685e-04 - mse: 3.9329e-08 - root_mean_squared_error: 1.9829e-04 - val_avg_m_diff: 21.7427 - val_loss: 2.5544e-08 - val_mae: 1.2480e-04 - val_mse: 5.1089e-08 - val_root_mean_squared_error: 2.2603e-04
# Epoch 957/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.3995 - loss: 2.0538e-08 - mae: 1.2825e-04 - mse: 4.1076e-08 - root_mean_squared_error: 2.0257e-04 - val_avg_m_diff: 22.1331 - val_loss: 2.5065e-08 - val_mae: 1.2643e-04 - val_mse: 5.0131e-08 - val_root_mean_squared_error: 2.2390e-04
# Epoch 958/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.4444 - loss: 2.1033e-08 - mae: 1.2851e-04 - mse: 4.2066e-08 - root_mean_squared_error: 2.0497e-04 - val_avg_m_diff: 22.6959 - val_loss: 2.5212e-08 - val_mae: 1.3043e-04 - val_mse: 5.0424e-08 - val_root_mean_squared_error: 2.2455e-04
# Epoch 959/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.5681 - loss: 1.9378e-08 - mae: 1.2327e-04 - mse: 3.8756e-08 - root_mean_squared_error: 1.9676e-04 - val_avg_m_diff: 19.8069 - val_loss: 2.6153e-08 - val_mae: 1.1347e-04 - val_mse: 5.2307e-08 - val_root_mean_squared_error: 2.2871e-04
# Epoch 960/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.4979 - loss: 2.0796e-08 - mae: 1.2912e-04 - mse: 4.1591e-08 - root_mean_squared_error: 2.0371e-04 - val_avg_m_diff: 26.5811 - val_loss: 3.5958e-08 - val_mae: 1.4991e-04 - val_mse: 7.1916e-08 - val_root_mean_squared_error: 2.6817e-04
# Epoch 961/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.7718 - loss: 1.9258e-08 - mae: 1.2448e-04 - mse: 3.8516e-08 - root_mean_squared_error: 1.9617e-04 - val_avg_m_diff: 19.1106 - val_loss: 2.2839e-08 - val_mae: 1.0899e-04 - val_mse: 4.5677e-08 - val_root_mean_squared_error: 2.1372e-04
# Epoch 962/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.5096 - loss: 1.8967e-08 - mae: 1.2328e-04 - mse: 3.7933e-08 - root_mean_squared_error: 1.9470e-04 - val_avg_m_diff: 23.1711 - val_loss: 2.5670e-08 - val_mae: 1.3183e-04 - val_mse: 5.1339e-08 - val_root_mean_squared_error: 2.2658e-04
# Epoch 963/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.1385 - loss: 1.9643e-08 - mae: 1.2675e-04 - mse: 3.9285e-08 - root_mean_squared_error: 1.9807e-04 - val_avg_m_diff: 21.3054 - val_loss: 2.7061e-08 - val_mae: 1.2187e-04 - val_mse: 5.4122e-08 - val_root_mean_squared_error: 2.3264e-04
# Epoch 964/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.6538 - loss: 1.9197e-08 - mae: 1.2402e-04 - mse: 3.8394e-08 - root_mean_squared_error: 1.9590e-04 - val_avg_m_diff: 23.9697 - val_loss: 2.6297e-08 - val_mae: 1.3783e-04 - val_mse: 5.2595e-08 - val_root_mean_squared_error: 2.2934e-04
# Epoch 965/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.7483 - loss: 1.9060e-08 - mae: 1.2447e-04 - mse: 3.8120e-08 - root_mean_squared_error: 1.9519e-04 - val_avg_m_diff: 22.4461 - val_loss: 2.6044e-08 - val_mae: 1.2943e-04 - val_mse: 5.2089e-08 - val_root_mean_squared_error: 2.2823e-04
# Epoch 966/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.7313 - loss: 1.9132e-08 - mae: 1.2441e-04 - mse: 3.8265e-08 - root_mean_squared_error: 1.9554e-04 - val_avg_m_diff: 24.3746 - val_loss: 2.7180e-08 - val_mae: 1.3987e-04 - val_mse: 5.4360e-08 - val_root_mean_squared_error: 2.3315e-04
# Epoch 967/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.8189 - loss: 2.1563e-08 - mae: 1.3070e-04 - mse: 4.3127e-08 - root_mean_squared_error: 2.0761e-04 - val_avg_m_diff: 20.8012 - val_loss: 2.2899e-08 - val_mae: 1.1907e-04 - val_mse: 4.5797e-08 - val_root_mean_squared_error: 2.1400e-04
# Epoch 968/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.6844 - loss: 1.9119e-08 - mae: 1.2427e-04 - mse: 3.8237e-08 - root_mean_squared_error: 1.9545e-04 - val_avg_m_diff: 23.6789 - val_loss: 2.6989e-08 - val_mae: 1.3254e-04 - val_mse: 5.3979e-08 - val_root_mean_squared_error: 2.3233e-04
# Epoch 969/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.6167 - loss: 2.0288e-08 - mae: 1.2958e-04 - mse: 4.0577e-08 - root_mean_squared_error: 2.0135e-04 - val_avg_m_diff: 23.9902 - val_loss: 2.8348e-08 - val_mae: 1.3888e-04 - val_mse: 5.6696e-08 - val_root_mean_squared_error: 2.3811e-04
# Epoch 970/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.3810 - loss: 2.0026e-08 - mae: 1.2827e-04 - mse: 4.0051e-08 - root_mean_squared_error: 2.0009e-04 - val_avg_m_diff: 21.8478 - val_loss: 2.4087e-08 - val_mae: 1.2629e-04 - val_mse: 4.8173e-08 - val_root_mean_squared_error: 2.1948e-04
# Epoch 971/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.6822 - loss: 1.9473e-08 - mae: 1.2393e-04 - mse: 3.8945e-08 - root_mean_squared_error: 1.9723e-04 - val_avg_m_diff: 20.5235 - val_loss: 2.2869e-08 - val_mae: 1.1855e-04 - val_mse: 4.5738e-08 - val_root_mean_squared_error: 2.1386e-04
# Epoch 972/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.8687 - loss: 1.9013e-08 - mae: 1.2536e-04 - mse: 3.8026e-08 - root_mean_squared_error: 1.9493e-04 - val_avg_m_diff: 19.8028 - val_loss: 2.2073e-08 - val_mae: 1.1409e-04 - val_mse: 4.4145e-08 - val_root_mean_squared_error: 2.1011e-04
# Epoch 973/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.9408 - loss: 1.9145e-08 - mae: 1.2566e-04 - mse: 3.8290e-08 - root_mean_squared_error: 1.9564e-04 - val_avg_m_diff: 23.4399 - val_loss: 2.5140e-08 - val_mae: 1.3537e-04 - val_mse: 5.0280e-08 - val_root_mean_squared_error: 2.2423e-04
# Epoch 974/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.8557 - loss: 1.9492e-08 - mae: 1.2474e-04 - mse: 3.8985e-08 - root_mean_squared_error: 1.9730e-04 - val_avg_m_diff: 20.1926 - val_loss: 2.2759e-08 - val_mae: 1.1556e-04 - val_mse: 4.5518e-08 - val_root_mean_squared_error: 2.1335e-04
# Epoch 975/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.6035 - loss: 2.0593e-08 - mae: 1.2990e-04 - mse: 4.1187e-08 - root_mean_squared_error: 2.0269e-04 - val_avg_m_diff: 31.2300 - val_loss: 4.4184e-08 - val_mae: 1.7609e-04 - val_mse: 8.8368e-08 - val_root_mean_squared_error: 2.9727e-04
# Epoch 976/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.8891 - loss: 2.1420e-08 - mae: 1.3062e-04 - mse: 4.2839e-08 - root_mean_squared_error: 2.0636e-04 - val_avg_m_diff: 23.1153 - val_loss: 2.5448e-08 - val_mae: 1.3254e-04 - val_mse: 5.0896e-08 - val_root_mean_squared_error: 2.2560e-04
# Epoch 977/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.7578 - loss: 1.9169e-08 - mae: 1.2447e-04 - mse: 3.8337e-08 - root_mean_squared_error: 1.9574e-04 - val_avg_m_diff: 22.0459 - val_loss: 2.6076e-08 - val_mae: 1.2501e-04 - val_mse: 5.2152e-08 - val_root_mean_squared_error: 2.2837e-04
# Epoch 978/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.7008 - loss: 1.9156e-08 - mae: 1.2431e-04 - mse: 3.8311e-08 - root_mean_squared_error: 1.9571e-04 - val_avg_m_diff: 18.6748 - val_loss: 2.0958e-08 - val_mae: 1.0638e-04 - val_mse: 4.1916e-08 - val_root_mean_squared_error: 2.0473e-04
# Epoch 979/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.1288 - loss: 1.9680e-08 - mae: 1.2667e-04 - mse: 3.9359e-08 - root_mean_squared_error: 1.9832e-04 - val_avg_m_diff: 20.5623 - val_loss: 2.2866e-08 - val_mae: 1.1818e-04 - val_mse: 4.5732e-08 - val_root_mean_squared_error: 2.1385e-04
# Epoch 980/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.7252 - loss: 1.9386e-08 - mae: 1.2412e-04 - mse: 3.8771e-08 - root_mean_squared_error: 1.9689e-04 - val_avg_m_diff: 23.0821 - val_loss: 2.4700e-08 - val_mae: 1.3217e-04 - val_mse: 4.9400e-08 - val_root_mean_squared_error: 2.2226e-04
# Epoch 981/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.7905 - loss: 2.0423e-08 - mae: 1.3046e-04 - mse: 4.0847e-08 - root_mean_squared_error: 2.0199e-04 - val_avg_m_diff: 18.6242 - val_loss: 2.2543e-08 - val_mae: 1.0696e-04 - val_mse: 4.5086e-08 - val_root_mean_squared_error: 2.1233e-04
# Epoch 982/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.4585 - loss: 1.8770e-08 - mae: 1.2286e-04 - mse: 3.7540e-08 - root_mean_squared_error: 1.9370e-04 - val_avg_m_diff: 22.3772 - val_loss: 2.5190e-08 - val_mae: 1.2804e-04 - val_mse: 5.0380e-08 - val_root_mean_squared_error: 2.2445e-04
# Epoch 983/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.4399 - loss: 1.8920e-08 - mae: 1.2278e-04 - mse: 3.7840e-08 - root_mean_squared_error: 1.9437e-04 - val_avg_m_diff: 25.0484 - val_loss: 3.0075e-08 - val_mae: 1.4269e-04 - val_mse: 6.0150e-08 - val_root_mean_squared_error: 2.4525e-04
# Epoch 984/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.5880 - loss: 1.8732e-08 - mae: 1.2336e-04 - mse: 3.7464e-08 - root_mean_squared_error: 1.9347e-04 - val_avg_m_diff: 22.9288 - val_loss: 2.5452e-08 - val_mae: 1.3015e-04 - val_mse: 5.0904e-08 - val_root_mean_squared_error: 2.2562e-04
# Epoch 985/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.2102 - loss: 2.0157e-08 - mae: 1.2715e-04 - mse: 4.0314e-08 - root_mean_squared_error: 2.0060e-04 - val_avg_m_diff: 23.0875 - val_loss: 2.6263e-08 - val_mae: 1.3233e-04 - val_mse: 5.2527e-08 - val_root_mean_squared_error: 2.2919e-04
# Epoch 986/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.2671 - loss: 1.9892e-08 - mae: 1.2740e-04 - mse: 3.9783e-08 - root_mean_squared_error: 1.9938e-04 - val_avg_m_diff: 22.8123 - val_loss: 2.7232e-08 - val_mae: 1.3151e-04 - val_mse: 5.4464e-08 - val_root_mean_squared_error: 2.3337e-04
# Epoch 987/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.2878 - loss: 1.9804e-08 - mae: 1.2726e-04 - mse: 3.9608e-08 - root_mean_squared_error: 1.9895e-04 - val_avg_m_diff: 19.2458 - val_loss: 2.2128e-08 - val_mae: 1.0987e-04 - val_mse: 4.4256e-08 - val_root_mean_squared_error: 2.1037e-04
# Epoch 988/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.0987 - loss: 2.0027e-08 - mae: 1.2679e-04 - mse: 4.0053e-08 - root_mean_squared_error: 1.9993e-04 - val_avg_m_diff: 19.4292 - val_loss: 2.1868e-08 - val_mae: 1.1060e-04 - val_mse: 4.3736e-08 - val_root_mean_squared_error: 2.0913e-04
# Epoch 989/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.7163 - loss: 1.9373e-08 - mae: 1.2464e-04 - mse: 3.8746e-08 - root_mean_squared_error: 1.9680e-04 - val_avg_m_diff: 24.7512 - val_loss: 2.9489e-08 - val_mae: 1.4177e-04 - val_mse: 5.8979e-08 - val_root_mean_squared_error: 2.4286e-04
# Epoch 990/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.8322 - loss: 1.9319e-08 - mae: 1.2485e-04 - mse: 3.8639e-08 - root_mean_squared_error: 1.9649e-04 - val_avg_m_diff: 20.7263 - val_loss: 2.3702e-08 - val_mae: 1.1815e-04 - val_mse: 4.7403e-08 - val_root_mean_squared_error: 2.1772e-04
# Epoch 991/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.0951 - loss: 2.0424e-08 - mae: 1.2671e-04 - mse: 4.0848e-08 - root_mean_squared_error: 2.0199e-04 - val_avg_m_diff: 20.0074 - val_loss: 2.2787e-08 - val_mae: 1.1387e-04 - val_mse: 4.5575e-08 - val_root_mean_squared_error: 2.1348e-04
# Epoch 992/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.5269 - loss: 1.8965e-08 - mae: 1.2317e-04 - mse: 3.7930e-08 - root_mean_squared_error: 1.9471e-04 - val_avg_m_diff: 21.3891 - val_loss: 2.2769e-08 - val_mae: 1.2179e-04 - val_mse: 4.5538e-08 - val_root_mean_squared_error: 2.1340e-04
# Epoch 993/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 22.0362 - loss: 1.9964e-08 - mae: 1.2635e-04 - mse: 3.9929e-08 - root_mean_squared_error: 1.9975e-04 - val_avg_m_diff: 19.5068 - val_loss: 2.1995e-08 - val_mae: 1.1089e-04 - val_mse: 4.3991e-08 - val_root_mean_squared_error: 2.0974e-04
# Epoch 994/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.5751 - loss: 1.8913e-08 - mae: 1.2354e-04 - mse: 3.7827e-08 - root_mean_squared_error: 1.9443e-04 - val_avg_m_diff: 29.9445 - val_loss: 3.6475e-08 - val_mae: 1.6946e-04 - val_mse: 7.2951e-08 - val_root_mean_squared_error: 2.7009e-04
# Epoch 995/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.4602 - loss: 2.0304e-08 - mae: 1.2834e-04 - mse: 4.0607e-08 - root_mean_squared_error: 2.0104e-04 - val_avg_m_diff: 19.3960 - val_loss: 2.1612e-08 - val_mae: 1.1106e-04 - val_mse: 4.3224e-08 - val_root_mean_squared_error: 2.0790e-04
# Epoch 996/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.1993 - loss: 1.8103e-08 - mae: 1.2133e-04 - mse: 3.6206e-08 - root_mean_squared_error: 1.9022e-04 - val_avg_m_diff: 21.8513 - val_loss: 2.5212e-08 - val_mae: 1.2564e-04 - val_mse: 5.0424e-08 - val_root_mean_squared_error: 2.2455e-04
# Epoch 997/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.9003 - loss: 1.9266e-08 - mae: 1.2529e-04 - mse: 3.8532e-08 - root_mean_squared_error: 1.9626e-04 - val_avg_m_diff: 18.7106 - val_loss: 2.1183e-08 - val_mae: 1.0744e-04 - val_mse: 4.2367e-08 - val_root_mean_squared_error: 2.0583e-04
# Epoch 998/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 22.3016 - loss: 1.9920e-08 - mae: 1.2800e-04 - mse: 3.9841e-08 - root_mean_squared_error: 1.9949e-04 - val_avg_m_diff: 24.6689 - val_loss: 2.6594e-08 - val_mae: 1.4129e-04 - val_mse: 5.3188e-08 - val_root_mean_squared_error: 2.3062e-04
# Epoch 999/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - avg_m_diff: 21.7250 - loss: 1.9004e-08 - mae: 1.2436e-04 - mse: 3.8008e-08 - root_mean_squared_error: 1.9488e-04 - val_avg_m_diff: 19.9304 - val_loss: 2.3706e-08 - val_mae: 1.1331e-04 - val_mse: 4.7413e-08 - val_root_mean_squared_error: 2.1774e-04
# Epoch 1000/1000
# 1268/1268 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - avg_m_diff: 21.2521 - loss: 1.8325e-08 - mae: 1.2161e-04 - mse: 3.6651e-08 - root_mean_squared_error: 1.9143e-04 - val_avg_m_diff: 22.6525 - val_loss: 2.5909e-08 - val_mae: 1.2997e-04 - val_mse: 5.1819e-08 - val_root_mean_squared_error: 2.2764e-04
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - avg_m_diff: 22.4888 - loss: 2.0614e-08 - mae: 1.2898e-04 - mse: 4.1228e-08 - root_mean_squared_error: 2.0260e-04
# [2.590947900671381e-08,
#  0.00012997060548514128,
#  5.181895446071394e-08,
#  22.65254783630371,
#  0.00022763776360079646]

# %%
## Save the model
model.save('model_v6_1.keras')
