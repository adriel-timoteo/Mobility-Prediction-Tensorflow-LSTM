# %% [markdown]
# <h2>DATA CLEANING</h2>
#
# Script ini digunakan untuk membersihkan data dari GrabPosisi jadi data yang lebih mudah untuk dimengerti dan dipelajari oleh model LSTMnya nanti. Proses Cleaning Data ini meliputi:
# - Mengurutkan Data berdasarkan trj_id lalu pingtimestamp agar data terurut dengan baik
# - Mengelompokkan data dan menjadikannya Pandas Multi Index Dataframe dengan trj_id sebagai index, untuk mempermudah pemisahan trajectories nantinya
# - Me-resample data (Data awal memiliki sampling rate 1 kali per **detik**, namun beberapa kali jarak antar ping bisa lebih dari 1 detik). Setelah resampling, data memiliki sampling rate 1 kali per **menit** dan konstan (Tidak ada jarak antar ping yang berbeda)
# <br/>
# Hasil dari data cleaning ini sudah diexport menjadi clean_data.csv, sehingga script ini tidak perlu dijalankan kecuali ingin mengubah proses data cleaning di atas.

# %%
## Import libraries
import pandas as pd
from pathlib import Path

# %%
# Read Data
data_dir = Path('../Mobility-Prediction-Tensorflow-LSTM/GrabPosisi')
full_df = pd.DataFrame()
for parquet_file in data_dir.glob("*.parquet"):
    print(f"Adding file: {parquet_file}")
    full_df = pd.concat([full_df, pd.read_parquet(parquet_file)], ignore_index=True)
# Out:
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00000-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00001-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00002-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00003-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00004-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00005-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00006-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00007-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00008-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet
# Adding file: ..\Mobility-Prediction-Tensorflow-LSTM\GrabPosisi\part-00009-8bbff892-97d2-4011-9961-703e38972569.c000.snappy.parquet

# %%
# Remove unnecessary columns (driving_mode, osname, accuracy)
train_df = full_df[['trj_id', 'pingtimestamp', 'rawlat', 'rawlng', 'speed', 'bearing']]

# Sort by trj_id and then pingtimestamp
train_df = train_df.sort_values(by=["trj_id", "pingtimestamp"])

# Convert pingtimestamp from unix timestamp to Pandas DateTime
train_df['pingtimestamp'] = pd.to_datetime(train_df['pingtimestamp'], unit='s')
print(train_df)
# Out:
#          trj_id  pingtimestamp    rawlat      rawlng  speed  bearing
# 29091989      1     1554992255 -6.197622  106.769017   5.58      180
# 29074360      1     1554992256 -6.197667  106.769007   5.33      177
# 10694992      1     1554992257 -6.197713  106.769012   5.43      177
# 10676471      1     1554992258 -6.197764  106.769020   5.84      178
# 22141074      1     1554992259 -6.197809  106.769018   5.28      179
# ...         ...            ...       ...         ...    ...      ...
# 19921434   9999     1555822630 -6.178844  106.841960   0.00        0
# 7604364    9999     1555822631 -6.178844  106.841960   0.00        0
# 25980783   9999     1555822632 -6.178844  106.841961   0.00        0
# 14850195   9999     1555822634 -6.178845  106.841963   0.00        0
# 19919728   9999     1555822635 -6.178845  106.841964   0.00        0
#
# [55988420 rows x 6 columns]

# %%
def reorganize_trj_id(df):
    unique_trj_ids = df['trj_id'].unique()
    trj_id_map = {old_id: new_id for new_id, old_id in enumerate(unique_trj_ids, start=1)}
    df['trj_id'] = df['trj_id'].map(trj_id_map)
    return df, max(trj_id_map.values())

def split_large_timestamp_gaps(group, start_id):
    group = group.reset_index(drop=True)

    # Calculate the difference between consecutive timestamps
    time_diff = group['pingtimestamp'].diff()

    # Identify rows where the difference is greater than 60 seconds
    large_gaps = time_diff > pd.Timedelta(seconds=60)

    # If there are large gaps, split the group
    if large_gaps.any():
        split_groups = []
        current_group = []
        current_trj_id = group['trj_id'].iloc[0]

        # Iterate through the rows
        for i, row in group.iterrows():
            if i == 0 or not large_gaps.iloc[i]:
                current_group.append(row)
            else:
                # Log the gap and split
                gap_duration = time_diff.iloc[i].total_seconds()
                new_trj_id = start_id
                start_id += 1

                size = len(current_group)
                size_split = len(group) - sum([len(g) for g in split_groups]) - len(current_group)
                print(f"Found {gap_duration} seconds gap in trj_id {current_trj_id}, splitting to {current_trj_id} with {size} steps and {new_trj_id} with {size_split} steps")
                
                # Assign trj_id to the current group
                for j in range(len(current_group)):
                    current_group[j]['trj_id'] = current_trj_id
                split_groups.append(pd.DataFrame(current_group))
                
                # Start a new group
                current_group = [row]
                current_trj_id = new_trj_id
        
        # Append the last group
        for j in range(len(current_group)):
            current_group[j]['trj_id'] = current_trj_id
        split_groups.append(pd.DataFrame(current_group))

        # Concatenate all new groups into one DataFrame
        return pd.concat(split_groups).reset_index(drop=True), start_id
    else:
        return group, start_id


# 1. Reorganize the original trj_id
df, max_trj_id = reorganize_trj_id(train_df)
print(df)

# 2. Apply the split function with the starting id for new trj_ids
start_id = max_trj_id + 1

result = []
for trj_id, group in df.groupby('trj_id'):
    split_group, start_id = split_large_timestamp_gaps(group, start_id)
    result.append(split_group)

split_df = pd.concat(result).reset_index(drop=True).set_index('trj_id', inplace=True)
# Out:
#           trj_id       pingtimestamp    rawlat      rawlng  speed  bearing
# 29091989       1 2019-04-11 14:17:35 -6.197622  106.769017   5.58      180
# 29074360       1 2019-04-11 14:17:36 -6.197667  106.769007   5.33      177
# 10694992       1 2019-04-11 14:17:37 -6.197713  106.769012   5.43      177
# 10676471       1 2019-04-11 14:17:38 -6.197764  106.769020   5.84      178
# 22141074       1 2019-04-11 14:17:39 -6.197809  106.769018   5.28      179
# ...          ...                 ...       ...         ...    ...      ...
# 19921434   55995 2019-04-21 04:57:10 -6.178844  106.841960   0.00        0
# 7604364    55995 2019-04-21 04:57:11 -6.178844  106.841960   0.00        0
# 25980783   55995 2019-04-21 04:57:12 -6.178844  106.841961   0.00        0
# 14850195   55995 2019-04-21 04:57:14 -6.178845  106.841963   0.00        0
# 19919728   55995 2019-04-21 04:57:15 -6.178845  106.841964   0.00        0
#
# [55988420 rows x 6 columns]
# Found 108.0 seconds gap in trj_id 6, splitting to 6 with 394 steps and 55996 with 827 steps
# Found 85.0 seconds gap in trj_id 9, splitting to 9 with 4001 steps and 55997 with 411 steps
# Found 73.0 seconds gap in trj_id 11, splitting to 11 with 1547 steps and 55998 with 58 steps
# Found 66.0 seconds gap in trj_id 12, splitting to 12 with 334 steps and 55999 with 330 steps
# Found 92.0 seconds gap in trj_id 55999, splitting to 55999 with 324 steps and 56000 with 6 steps
# Found 93.0 seconds gap in trj_id 17, splitting to 17 with 289 steps and 56001 with 75 steps
# Found 78.0 seconds gap in trj_id 19, splitting to 19 with 828 steps and 56002 with 324 steps
# Found 65.0 seconds gap in trj_id 26, splitting to 26 with 178 steps and 56003 with 308 steps
# Found 101.0 seconds gap in trj_id 34, splitting to 34 with 1626 steps and 56004 with 1143 steps
# Found 97.0 seconds gap in trj_id 56004, splitting to 56004 with 20 steps and 56005 with 1123 steps
# Found 62.0 seconds gap in trj_id 43, splitting to 43 with 1138 steps and 56006 with 472 steps
# Found 649.0 seconds gap in trj_id 56006, splitting to 56006 with 51 steps and 56007 with 421 steps
# Found 104.0 seconds gap in trj_id 48, splitting to 48 with 10 steps and 56008 with 1035 steps
# Found 87.0 seconds gap in trj_id 56008, splitting to 56008 with 404 steps and 56009 with 631 steps
# Found 66.0 seconds gap in trj_id 50, splitting to 50 with 148 steps and 56010 with 728 steps
# Found 101.0 seconds gap in trj_id 52, splitting to 52 with 3056 steps and 56011 with 1475 steps
# Found 133.0 seconds gap in trj_id 56011, splitting to 56011 with 1337 steps and 56012 with 138 steps
# Found 62.0 seconds gap in trj_id 54, splitting to 54 with 6 steps and 56013 with 343 steps
# Found 90.0 seconds gap in trj_id 55, splitting to 55 with 264 steps and 56014 with 170 steps
# Found 104.0 seconds gap in trj_id 58, splitting to 58 with 11 steps and 56015 with 361 steps
# Found 68.0 seconds gap in trj_id 59, splitting to 59 with 451 steps and 56016 with 232 steps
# Found 67.0 seconds gap in trj_id 56016, splitting to 56016 with 73 steps and 56017 with 159 steps
# Found 83.0 seconds gap in trj_id 56017, splitting to 56017 with 55 steps and 56018 with 104 steps
# Found 68.0 seconds gap in trj_id 63, splitting to 63 with 326 steps and 56019 with 175 steps
# Found 69.0 seconds gap in trj_id 56019, splitting to 56019 with 148 steps and 56020 with 27 steps
# Found 130.0 seconds gap in trj_id 56020, splitting to 56020 with 22 steps and 56021 with 5 steps
# Found 71.0 seconds gap in trj_id 65, splitting to 65 with 601 steps and 56022 with 179 steps
# Found 62.0 seconds gap in trj_id 66, splitting to 66 with 609 steps and 56023 with 2018 steps
# Found 65.0 seconds gap in trj_id 56023, splitting to 56023 with 50 steps and 56024 with 1968 steps
# Found 86.0 seconds gap in trj_id 69, splitting to 69 with 191 steps and 56025 with 400 steps
# Found 94.0 seconds gap in trj_id 72, splitting to 72 with 536 steps and 56026 with 351 steps
# Found 82.0 seconds gap in trj_id 78, splitting to 78 with 343 steps and 56027 with 205 steps
# Found 150.0 seconds gap in trj_id 86, splitting to 86 with 333 steps and 56028 with 3 steps
# Found 89.0 seconds gap in trj_id 89, splitting to 89 with 1179 steps and 56029 with 415 steps
# Found 86.0 seconds gap in trj_id 94, splitting to 94 with 148 steps and 56030 with 562 steps
# Found 128.0 seconds gap in trj_id 56030, splitting to 56030 with 84 steps and 56031 with 478 steps
# Found 62.0 seconds gap in trj_id 97, splitting to 97 with 103 steps and 56032 with 495 steps
# Found 76.0 seconds gap in trj_id 99, splitting to 99 with 322 steps and 56033 with 490 steps
# Found 62.0 seconds gap in trj_id 101, splitting to 101 with 191 steps and 56034 with 107 steps
# Found 144.0 seconds gap in trj_id 108, splitting to 108 with 104 steps and 56035 with 688 steps
# Found 76.0 seconds gap in trj_id 109, splitting to 109 with 1455 steps and 56036 with 281 steps
# Found 74.0 seconds gap in trj_id 111, splitting to 111 with 264 steps and 56037 with 82 steps
# Found 67.0 seconds gap in trj_id 116, splitting to 116 with 2440 steps and 56038 with 505 steps
# Found 61.0 seconds gap in trj_id 120, splitting to 120 with 7 steps and 56039 with 1591 steps
# Found 88.0 seconds gap in trj_id 56039, splitting to 56039 with 1191 steps and 56040 with 400 steps
# Found 94.0 seconds gap in trj_id 128, splitting to 128 with 819 steps and 56041 with 255 steps
# Found 78.0 seconds gap in trj_id 130, splitting to 130 with 91 steps and 56042 with 506 steps
# Found 65.0 seconds gap in trj_id 56042, splitting to 56042 with 14 steps and 56043 with 492 steps
# Found 186.0 seconds gap in trj_id 132, splitting to 132 with 1891 steps and 56044 with 713 steps
# Found 86.0 seconds gap in trj_id 138, splitting to 138 with 40 steps and 56045 with 397 steps
# Found 161.0 seconds gap in trj_id 56045, splitting to 56045 with 8 steps and 56046 with 389 steps
# Found 76.0 seconds gap in trj_id 56046, splitting to 56046 with 165 steps and 56047 with 224 steps
# Found 68.0 seconds gap in trj_id 143, splitting to 143 with 200 steps and 56048 with 1020 steps
# Found 81.0 seconds gap in trj_id 146, splitting to 146 with 769 steps and 56049 with 51 steps
# Found 61.0 seconds gap in trj_id 155, splitting to 155 with 1 steps and 56050 with 516 steps
# Found 80.0 seconds gap in trj_id 160, splitting to 160 with 490 steps and 56051 with 15 steps
# Found 74.0 seconds gap in trj_id 161, splitting to 161 with 523 steps and 56052 with 41 steps
# Found 166.0 seconds gap in trj_id 166, splitting to 166 with 116 steps and 56053 with 351 steps
# Found 119.0 seconds gap in trj_id 173, splitting to 173 with 1405 steps and 56054 with 1335 steps
# Found 133.0 seconds gap in trj_id 56054, splitting to 56054 with 283 steps and 56055 with 1052 steps
# Found 63.0 seconds gap in trj_id 175, splitting to 175 with 659 steps and 56056 with 55 steps
# Found 247.0 seconds gap in trj_id 181, splitting to 181 with 345 steps and 56057 with 526 steps
# Found 152.0 seconds gap in trj_id 185, splitting to 185 with 40 steps and 56058 with 1650 steps
# Found 94.0 seconds gap in trj_id 56058, splitting to 56058 with 1051 steps and 56059 with 599 steps
# Found 63.0 seconds gap in trj_id 56059, splitting to 56059 with 594 steps and 56060 with 5 steps
# Found 178.0 seconds gap in trj_id 188, splitting to 188 with 350 steps and 56061 with 279 steps
# Found 206.0 seconds gap in trj_id 56061, splitting to 56061 with 274 steps and 56062 with 5 steps
# Found 239.0 seconds gap in trj_id 190, splitting to 190 with 1238 steps and 56063 with 103 steps
# Found 130.0 seconds gap in trj_id 192, splitting to 192 with 114 steps and 56064 with 1064 steps
# Found 82.0 seconds gap in trj_id 195, splitting to 195 with 62 steps and 56065 with 1780 steps
# Found 78.0 seconds gap in trj_id 56065, splitting to 56065 with 1542 steps and 56066 with 238 steps
# Found 84.0 seconds gap in trj_id 196, splitting to 196 with 985 steps and 56067 with 251 steps
# Found 142.0 seconds gap in trj_id 201, splitting to 201 with 724 steps and 56068 with 53 steps
# Found 128.0 seconds gap in trj_id 203, splitting to 203 with 1262 steps and 56069 with 256 steps
# Found 77.0 seconds gap in trj_id 205, splitting to 205 with 71 steps and 56070 with 275 steps
# Found 463.0 seconds gap in trj_id 210, splitting to 210 with 5871 steps and 56071 with 147 steps
# Found 62.0 seconds gap in trj_id 212, splitting to 212 with 644 steps and 56072 with 514 steps
# Found 215.0 seconds gap in trj_id 213, splitting to 213 with 1379 steps and 56073 with 263 steps
# Found 79.0 seconds gap in trj_id 214, splitting to 214 with 1057 steps and 56074 with 81 steps
# Found 116.0 seconds gap in trj_id 218, splitting to 218 with 249 steps and 56075 with 290 steps
# Found 102.0 seconds gap in trj_id 56075, splitting to 56075 with 51 steps and 56076 with 239 steps
# Found 73.0 seconds gap in trj_id 220, splitting to 220 with 1277 steps and 56077 with 130 steps
# Found 90.0 seconds gap in trj_id 225, splitting to 225 with 143 steps and 56078 with 445 steps
# Found 66.0 seconds gap in trj_id 231, splitting to 231 with 76 steps and 56079 with 481 steps
# Found 63.0 seconds gap in trj_id 234, splitting to 234 with 122 steps and 56080 with 225 steps
# Found 79.0 seconds gap in trj_id 56080, splitting to 56080 with 172 steps and 56081 with 53 steps
# Found 74.0 seconds gap in trj_id 236, splitting to 236 with 857 steps and 56082 with 30 steps
# Found 63.0 seconds gap in trj_id 56082, splitting to 56082 with 15 steps and 56083 with 15 steps
# Found 120.0 seconds gap in trj_id 238, splitting to 238 with 1612 steps and 56084 with 705 steps
# Found 64.0 seconds gap in trj_id 239, splitting to 239 with 441 steps and 56085 with 9 steps
# Found 129.0 seconds gap in trj_id 246, splitting to 246 with 368 steps and 56086 with 1743 steps
# Found 132.0 seconds gap in trj_id 56086, splitting to 56086 with 1 steps and 56087 with 1742 steps
# Found 113.0 seconds gap in trj_id 56087, splitting to 56087 with 11 steps and 56088 with 1731 steps
# Found 72.0 seconds gap in trj_id 56088, splitting to 56088 with 2 steps and 56089 with 1729 steps
# Found 79.0 seconds gap in trj_id 56089, splitting to 56089 with 84 steps and 56090 with 1645 steps
# Found 61.0 seconds gap in trj_id 56090, splitting to 56090 with 1 steps and 56091 with 1644 steps
# Found 133.0 seconds gap in trj_id 56091, splitting to 56091 with 48 steps and 56092 with 1596 steps
# Found 74.0 seconds gap in trj_id 250, splitting to 250 with 1647 steps and 56093 with 776 steps
# Found 107.0 seconds gap in trj_id 56093, splitting to 56093 with 67 steps and 56094 with 709 steps
# Found 62.0 seconds gap in trj_id 251, splitting to 251 with 643 steps and 56095 with 27 steps
# Found 61.0 seconds gap in trj_id 254, splitting to 254 with 68 steps and 56096 with 200 steps
# Found 304.0 seconds gap in trj_id 56096, splitting to 56096 with 1 steps and 56097 with 199 steps
# Found 64.0 seconds gap in trj_id 258, splitting to 258 with 948 steps and 56098 with 104 steps
# Found 64.0 seconds gap in trj_id 261, splitting to 261 with 16 steps and 56099 with 809 steps
# Found 107.0 seconds gap in trj_id 269, splitting to 269 with 649 steps and 56100 with 536 steps
# Found 61.0 seconds gap in trj_id 56100, splitting to 56100 with 93 steps and 56101 with 443 steps
# Found 112.0 seconds gap in trj_id 274, splitting to 274 with 212 steps and 56102 with 746 steps
# Found 67.0 seconds gap in trj_id 56102, splitting to 56102 with 39 steps and 56103 with 707 steps
# Found 72.0 seconds gap in trj_id 275, splitting to 275 with 160 steps and 56104 with 250 steps
# Found 136.0 seconds gap in trj_id 278, splitting to 278 with 846 steps and 56105 with 65 steps
# Found 70.0 seconds gap in trj_id 289, splitting to 289 with 195 steps and 56106 with 884 steps
# Found 144.0 seconds gap in trj_id 295, splitting to 295 with 265 steps and 56107 with 332 steps
# Found 68.0 seconds gap in trj_id 297, splitting to 297 with 1384 steps and 56108 with 1102 steps
# Found 338.0 seconds gap in trj_id 301, splitting to 301 with 2613 steps and 56109 with 492 steps
# Found 157.0 seconds gap in trj_id 56109, splitting to 56109 with 23 steps and 56110 with 469 steps
# Found 74.0 seconds gap in trj_id 311, splitting to 311 with 922 steps and 56111 with 155 steps
# Found 62.0 seconds gap in trj_id 56111, splitting to 56111 with 112 steps and 56112 with 43 steps
# Found 77.0 seconds gap in trj_id 315, splitting to 315 with 911 steps and 56113 with 415 steps
# Found 111.0 seconds gap in trj_id 328, splitting to 328 with 197 steps and 56114 with 1405 steps
# Found 94.0 seconds gap in trj_id 329, splitting to 329 with 65 steps and 56115 with 636 steps
# Found 73.0 seconds gap in trj_id 56115, splitting to 56115 with 237 steps and 56116 with 399 steps
# Found 78.0 seconds gap in trj_id 347, splitting to 347 with 269 steps and 56117 with 870 steps
# Found 123.0 seconds gap in trj_id 56117, splitting to 56117 with 1 steps and 56118 with 869 steps
# Found 68.0 seconds gap in trj_id 358, splitting to 358 with 199 steps and 56119 with 832 steps
# Found 246.0 seconds gap in trj_id 364, splitting to 364 with 73 steps and 56120 with 377 steps
# Found 116.0 seconds gap in trj_id 366, splitting to 366 with 124 steps and 56121 with 470 steps
# Found 111.0 seconds gap in trj_id 367, splitting to 367 with 378 steps and 56122 with 886 steps
# Found 83.0 seconds gap in trj_id 371, splitting to 371 with 76 steps and 56123 with 490 steps
# Found 64.0 seconds gap in trj_id 380, splitting to 380 with 68 steps and 56124 with 251 steps
# Found 76.0 seconds gap in trj_id 388, splitting to 388 with 240 steps and 56125 with 55 steps
# Found 73.0 seconds gap in trj_id 396, splitting to 396 with 1315 steps and 56126 with 527 steps
# Found 127.0 seconds gap in trj_id 397, splitting to 397 with 2 steps and 56127 with 1099 steps
# Found 84.0 seconds gap in trj_id 401, splitting to 401 with 784 steps and 56128 with 121 steps
# Found 64.0 seconds gap in trj_id 407, splitting to 407 with 302 steps and 56129 with 8 steps
# Found 104.0 seconds gap in trj_id 409, splitting to 409 with 789 steps and 56130 with 123 steps
# Found 67.0 seconds gap in trj_id 410, splitting to 410 with 396 steps and 56131 with 241 steps
# Found 126.0 seconds gap in trj_id 56131, splitting to 56131 with 1 steps and 56132 with 240 steps
# Found 78.0 seconds gap in trj_id 56132, splitting to 56132 with 55 steps and 56133 with 185 steps
# Found 77.0 seconds gap in trj_id 412, splitting to 412 with 1186 steps and 56134 with 400 steps
# Found 89.0 seconds gap in trj_id 56134, splitting to 56134 with 82 steps and 56135 with 318 steps
# Found 69.0 seconds gap in trj_id 413, splitting to 413 with 46 steps and 56136 with 15449 steps
# Found 64.0 seconds gap in trj_id 56136, splitting to 56136 with 504 steps and 56137 with 14945 steps
# Found 82.0 seconds gap in trj_id 56137, splitting to 56137 with 87 steps and 56138 with 14858 steps
# Found 229.0 seconds gap in trj_id 56138, splitting to 56138 with 210 steps and 56139 with 14648 steps
# Found 99.0 seconds gap in trj_id 56139, splitting to 56139 with 1848 steps and 56140 with 12800 steps
# Found 96.0 seconds gap in trj_id 56140, splitting to 56140 with 4817 steps and 56141 with 7983 steps
# Found 153.0 seconds gap in trj_id 56141, splitting to 56141 with 311 steps and 56142 with 7672 steps
# Found 247.0 seconds gap in trj_id 56142, splitting to 56142 with 64 steps and 56143 with 7608 steps
# Found 123.0 seconds gap in trj_id 56143, splitting to 56143 with 217 steps and 56144 with 7391 steps
# Found 70.0 seconds gap in trj_id 56144, splitting to 56144 with 55 steps and 56145 with 7336 steps
# Found 94.0 seconds gap in trj_id 56145, splitting to 56145 with 57 steps and 56146 with 7279 steps
# Found 157.0 seconds gap in trj_id 56146, splitting to 56146 with 119 steps and 56147 with 7160 steps
# Found 63.0 seconds gap in trj_id 56147, splitting to 56147 with 194 steps and 56148 with 6966 steps
# Found 143.0 seconds gap in trj_id 56148, splitting to 56148 with 277 steps and 56149 with 6689 steps
# Found 226.0 seconds gap in trj_id 56149, splitting to 56149 with 47 steps and 56150 with 6642 steps
# Found 106.0 seconds gap in trj_id 56150, splitting to 56150 with 14 steps and 56151 with 6628 steps
# Found 70.0 seconds gap in trj_id 56151, splitting to 56151 with 103 steps and 56152 with 6525 steps
# Found 80.0 seconds gap in trj_id 56152, splitting to 56152 with 36 steps and 56153 with 6489 steps
# Found 83.0 seconds gap in trj_id 56153, splitting to 56153 with 159 steps and 56154 with 6330 steps
# Found 75.0 seconds gap in trj_id 56154, splitting to 56154 with 14 steps and 56155 with 6316 steps
# Found 136.0 seconds gap in trj_id 56155, splitting to 56155 with 267 steps and 56156 with 6049 steps
# Found 66.0 seconds gap in trj_id 56156, splitting to 56156 with 58 steps and 56157 with 5991 steps
# Found 64.0 seconds gap in trj_id 56157, splitting to 56157 with 204 steps and 56158 with 5787 steps
# Found 68.0 seconds gap in trj_id 56158, splitting to 56158 with 14 steps and 56159 with 5773 steps
# Found 118.0 seconds gap in trj_id 56159, splitting to 56159 with 142 steps and 56160 with 5631 steps
# Found 70.0 seconds gap in trj_id 56160, splitting to 56160 with 18 steps and 56161 with 5613 steps
# Found 120.0 seconds gap in trj_id 56161, splitting to 56161 with 3103 steps and 56162 with 2510 steps
# Found 193.0 seconds gap in trj_id 56162, splitting to 56162 with 15 steps and 56163 with 2495 steps
# Found 107.0 seconds gap in trj_id 56163, splitting to 56163 with 234 steps and 56164 with 2261 steps
# Found 166.0 seconds gap in trj_id 56164, splitting to 56164 with 96 steps and 56165 with 2165 steps
# Found 379.0 seconds gap in trj_id 56165, splitting to 56165 with 431 steps and 56166 with 1734 steps
# Found 324.0 seconds gap in trj_id 56166, splitting to 56166 with 20 steps and 56167 with 1714 steps
# Found 115.0 seconds gap in trj_id 417, splitting to 417 with 277 steps and 56168 with 210 steps
# Found 79.0 seconds gap in trj_id 418, splitting to 418 with 54 steps and 56169 with 1169 steps
# Found 177.0 seconds gap in trj_id 56169, splitting to 56169 with 1164 steps and 56170 with 5 steps
# Found 70.0 seconds gap in trj_id 422, splitting to 422 with 55 steps and 56171 with 2105 steps
# Found 63.0 seconds gap in trj_id 423, splitting to 423 with 324 steps and 56172 with 708 steps
# Found 68.0 seconds gap in trj_id 430, splitting to 430 with 297 steps and 56173 with 640 steps
# Found 66.0 seconds gap in trj_id 434, splitting to 434 with 351 steps and 56174 with 804 steps
# Found 76.0 seconds gap in trj_id 56174, splitting to 56174 with 439 steps and 56175 with 365 steps
# Found 80.0 seconds gap in trj_id 437, splitting to 437 with 3 steps and 56176 with 365 steps
# Found 61.0 seconds gap in trj_id 440, splitting to 440 with 528 steps and 56177 with 1169 steps
# Found 61.0 seconds gap in trj_id 442, splitting to 442 with 326 steps and 56178 with 441 steps
# Found 64.0 seconds gap in trj_id 443, splitting to 443 with 249 steps and 56179 with 331 steps
# Found 82.0 seconds gap in trj_id 444, splitting to 444 with 115 steps and 56180 with 658 steps
# Found 66.0 seconds gap in trj_id 448, splitting to 448 with 61 steps and 56181 with 1464 steps
# Found 83.0 seconds gap in trj_id 450, splitting to 450 with 181 steps and 56182 with 578 steps
# Found 143.0 seconds gap in trj_id 454, splitting to 454 with 306 steps and 56183 with 120 steps
# Found 65.0 seconds gap in trj_id 456, splitting to 456 with 773 steps and 56184 with 1822 steps
# Found 61.0 seconds gap in trj_id 457, splitting to 457 with 178 steps and 56185 with 782 steps
# Found 132.0 seconds gap in trj_id 470, splitting to 470 with 4529 steps and 56186 with 54 steps
# Found 67.0 seconds gap in trj_id 489, splitting to 489 with 755 steps and 56187 with 190 steps
# Found 100.0 seconds gap in trj_id 491, splitting to 491 with 146 steps and 56188 with 400 steps
# Found 177.0 seconds gap in trj_id 56188, splitting to 56188 with 1 steps and 56189 with 399 steps
# Found 105.0 seconds gap in trj_id 56189, splitting to 56189 with 59 steps and 56190 with 340 steps
# Found 96.0 seconds gap in trj_id 494, splitting to 494 with 2070 steps and 56191 with 708 steps
# Found 104.0 seconds gap in trj_id 498, splitting to 498 with 395 steps and 56192 with 40 steps
# Found 166.0 seconds gap in trj_id 500, splitting to 500 with 391 steps and 56193 with 1 steps
# Found 74.0 seconds gap in trj_id 504, splitting to 504 with 270 steps and 56194 with 4972 steps
# Found 63.0 seconds gap in trj_id 507, splitting to 507 with 309 steps and 56195 with 82 steps
# Found 84.0 seconds gap in trj_id 509, splitting to 509 with 487 steps and 56196 with 1559 steps
# Found 84.0 seconds gap in trj_id 56196, splitting to 56196 with 40 steps and 56197 with 1519 steps
# Found 188.0 seconds gap in trj_id 56197, splitting to 56197 with 8 steps and 56198 with 1511 steps
# Found 86.0 seconds gap in trj_id 56198, splitting to 56198 with 189 steps and 56199 with 1322 steps
# Found 62.0 seconds gap in trj_id 56199, splitting to 56199 with 579 steps and 56200 with 743 steps
# Found 330.0 seconds gap in trj_id 56200, splitting to 56200 with 346 steps and 56201 with 397 steps
# Found 129.0 seconds gap in trj_id 528, splitting to 528 with 290 steps and 56202 with 648 steps
# Found 64.0 seconds gap in trj_id 530, splitting to 530 with 233 steps and 56203 with 794 steps
# Found 95.0 seconds gap in trj_id 536, splitting to 536 with 186 steps and 56204 with 311 steps
# Found 86.0 seconds gap in trj_id 541, splitting to 541 with 41 steps and 56205 with 903 steps
# Found 260.0 seconds gap in trj_id 56205, splitting to 56205 with 140 steps and 56206 with 763 steps
# Found 364.0 seconds gap in trj_id 554, splitting to 554 with 1229 steps and 56207 with 79 steps
# Found 127.0 seconds gap in trj_id 555, splitting to 555 with 580 steps and 56208 with 1961 steps
# Found 71.0 seconds gap in trj_id 56208, splitting to 56208 with 69 steps and 56209 with 1892 steps
# Found 88.0 seconds gap in trj_id 56209, splitting to 56209 with 445 steps and 56210 with 1447 steps
# Found 75.0 seconds gap in trj_id 577, splitting to 577 with 58 steps and 56211 with 916 steps
# Found 88.0 seconds gap in trj_id 581, splitting to 581 with 359 steps and 56212 with 5 steps
# Found 68.0 seconds gap in trj_id 583, splitting to 583 with 41 steps and 56213 with 453 steps
# Found 86.0 seconds gap in trj_id 56213, splitting to 56213 with 73 steps and 56214 with 380 steps
# Found 67.0 seconds gap in trj_id 56214, splitting to 56214 with 241 steps and 56215 with 139 steps
# Found 81.0 seconds gap in trj_id 585, splitting to 585 with 14 steps and 56216 with 637 steps
# Found 119.0 seconds gap in trj_id 586, splitting to 586 with 409 steps and 56217 with 3186 steps
# Found 68.0 seconds gap in trj_id 589, splitting to 589 with 253 steps and 56218 with 303 steps
# Found 80.0 seconds gap in trj_id 592, splitting to 592 with 96 steps and 56219 with 1798 steps
# Found 283.0 seconds gap in trj_id 56219, splitting to 56219 with 1750 steps and 56220 with 48 steps
# Found 140.0 seconds gap in trj_id 595, splitting to 595 with 73 steps and 56221 with 179 steps
# Found 76.0 seconds gap in trj_id 596, splitting to 596 with 300 steps and 56222 with 451 steps
# Found 183.0 seconds gap in trj_id 598, splitting to 598 with 1484 steps and 56223 with 7 steps
# Found 91.0 seconds gap in trj_id 601, splitting to 601 with 449 steps and 56224 with 3 steps
# Found 74.0 seconds gap in trj_id 607, splitting to 607 with 91 steps and 56225 with 1034 steps
# Found 118.0 seconds gap in trj_id 56225, splitting to 56225 with 362 steps and 56226 with 672 steps
# Found 63.0 seconds gap in trj_id 621, splitting to 621 with 92 steps and 56227 with 777 steps
# Found 61.0 seconds gap in trj_id 626, splitting to 626 with 1784 steps and 56228 with 343 steps
# Found 61.0 seconds gap in trj_id 56228, splitting to 56228 with 1 steps and 56229 with 342 steps
# Found 73.0 seconds gap in trj_id 56229, splitting to 56229 with 24 steps and 56230 with 318 steps
# Found 88.0 seconds gap in trj_id 629, splitting to 629 with 43 steps and 56231 with 407 steps
# Found 63.0 seconds gap in trj_id 633, splitting to 633 with 80 steps and 56232 with 1836 steps
# Found 135.0 seconds gap in trj_id 56232, splitting to 56232 with 56 steps and 56233 with 1780 steps
# Found 240.0 seconds gap in trj_id 56233, splitting to 56233 with 694 steps and 56234 with 1086 steps
# Found 230.0 seconds gap in trj_id 56234, splitting to 56234 with 77 steps and 56235 with 1009 steps
# Found 95.0 seconds gap in trj_id 636, splitting to 636 with 707 steps and 56236 with 538 steps
# Found 90.0 seconds gap in trj_id 639, splitting to 639 with 293 steps and 56237 with 73 steps
# Found 79.0 seconds gap in trj_id 644, splitting to 644 with 157 steps and 56238 with 197 steps
# Found 61.0 seconds gap in trj_id 646, splitting to 646 with 293 steps and 56239 with 1005 steps
# Found 100.0 seconds gap in trj_id 659, splitting to 659 with 140 steps and 56240 with 2374 steps
# Found 532.0 seconds gap in trj_id 56240, splitting to 56240 with 16 steps and 56241 with 2358 steps
# Found 1041.0 seconds gap in trj_id 56241, splitting to 56241 with 17 steps and 56242 with 2341 steps
# Found 84.0 seconds gap in trj_id 660, splitting to 660 with 603 steps and 56243 with 266 steps
# Found 62.0 seconds gap in trj_id 664, splitting to 664 with 12 steps and 56244 with 1367 steps
# Found 90.0 seconds gap in trj_id 669, splitting to 669 with 398 steps and 56245 with 1102 steps
# Found 75.0 seconds gap in trj_id 56245, splitting to 56245 with 137 steps and 56246 with 965 steps
# Found 85.0 seconds gap in trj_id 670, splitting to 670 with 1823 steps and 56247 with 208 steps
# Found 65.0 seconds gap in trj_id 671, splitting to 671 with 331 steps and 56248 with 1521 steps
# Found 120.0 seconds gap in trj_id 675, splitting to 675 with 427 steps and 56249 with 1 steps
# Found 90.0 seconds gap in trj_id 677, splitting to 677 with 776 steps and 56250 with 77 steps
# Found 68.0 seconds gap in trj_id 683, splitting to 683 with 77 steps and 56251 with 932 steps
# Found 94.0 seconds gap in trj_id 689, splitting to 689 with 749 steps and 56252 with 154 steps
# Found 65.0 seconds gap in trj_id 56252, splitting to 56252 with 14 steps and 56253 with 140 steps
# Found 79.0 seconds gap in trj_id 690, splitting to 690 with 675 steps and 56254 with 8 steps
# Found 102.0 seconds gap in trj_id 691, splitting to 691 with 96 steps and 56255 with 3381 steps
# Found 121.0 seconds gap in trj_id 700, splitting to 700 with 109 steps and 56256 with 594 steps
# Found 72.0 seconds gap in trj_id 56256, splitting to 56256 with 176 steps and 56257 with 418 steps
# Found 96.0 seconds gap in trj_id 705, splitting to 705 with 603 steps and 56258 with 205 steps
# Found 90.0 seconds gap in trj_id 56258, splitting to 56258 with 195 steps and 56259 with 10 steps
# Found 77.0 seconds gap in trj_id 706, splitting to 706 with 171 steps and 56260 with 1321 steps
# Found 182.0 seconds gap in trj_id 56260, splitting to 56260 with 1248 steps and 56261 with 73 steps
# Found 72.0 seconds gap in trj_id 707, splitting to 707 with 14 steps and 56262 with 265 steps
# Found 73.0 seconds gap in trj_id 709, splitting to 709 with 99 steps and 56263 with 546 steps
# Found 105.0 seconds gap in trj_id 722, splitting to 722 with 75 steps and 56264 with 840 steps
# Found 106.0 seconds gap in trj_id 725, splitting to 725 with 12 steps and 56265 with 695 steps
# Found 271.0 seconds gap in trj_id 56265, splitting to 56265 with 13 steps and 56266 with 682 steps
# Found 193.0 seconds gap in trj_id 730, splitting to 730 with 29 steps and 56267 with 1947 steps
# Found 86.0 seconds gap in trj_id 56267, splitting to 56267 with 817 steps and 56268 with 1130 steps
# Found 151.0 seconds gap in trj_id 56268, splitting to 56268 with 18 steps and 56269 with 1112 steps
# Found 94.0 seconds gap in trj_id 733, splitting to 733 with 597 steps and 56270 with 360 steps
# Found 82.0 seconds gap in trj_id 735, splitting to 735 with 296 steps and 56271 with 453 steps
# Found 76.0 seconds gap in trj_id 739, splitting to 739 with 305 steps and 56272 with 332 steps
# Found 95.0 seconds gap in trj_id 744, splitting to 744 with 333 steps and 56273 with 279 steps
# Found 76.0 seconds gap in trj_id 745, splitting to 745 with 67 steps and 56274 with 790 steps
# Found 92.0 seconds gap in trj_id 747, splitting to 747 with 236 steps and 56275 with 1412 steps
# Found 117.0 seconds gap in trj_id 751, splitting to 751 with 2401 steps and 56276 with 743 steps
# Found 71.0 seconds gap in trj_id 56276, splitting to 56276 with 82 steps and 56277 with 661 steps
# Found 83.0 seconds gap in trj_id 752, splitting to 752 with 1147 steps and 56278 with 226 steps
# Found 88.0 seconds gap in trj_id 758, splitting to 758 with 45 steps and 56279 with 952 steps
# Found 71.0 seconds gap in trj_id 767, splitting to 767 with 126 steps and 56280 with 301 steps
# Found 61.0 seconds gap in trj_id 769, splitting to 769 with 353 steps and 56281 with 35 steps
# Found 586.0 seconds gap in trj_id 770, splitting to 770 with 477 steps and 56282 with 52 steps
# Found 61.0 seconds gap in trj_id 774, splitting to 774 with 4662 steps and 56283 with 1100 steps
# Found 163.0 seconds gap in trj_id 56283, splitting to 56283 with 885 steps and 56284 with 215 steps
# Found 212.0 seconds gap in trj_id 56284, splitting to 56284 with 150 steps and 56285 with 65 steps
# Found 69.0 seconds gap in trj_id 775, splitting to 775 with 234 steps and 56286 with 402 steps
# Found 63.0 seconds gap in trj_id 786, splitting to 786 with 286 steps and 56287 with 882 steps
# Found 92.0 seconds gap in trj_id 787, splitting to 787 with 287 steps and 56288 with 704 steps
# Found 127.0 seconds gap in trj_id 788, splitting to 788 with 69 steps and 56289 with 408 steps
# Found 110.0 seconds gap in trj_id 56289, splitting to 56289 with 1 steps and 56290 with 407 steps
# Found 71.0 seconds gap in trj_id 56290, splitting to 56290 with 1 steps and 56291 with 406 steps
# Found 127.0 seconds gap in trj_id 790, splitting to 790 with 1373 steps and 56292 with 75 steps
# Found 94.0 seconds gap in trj_id 791, splitting to 791 with 2041 steps and 56293 with 118 steps
# Found 78.0 seconds gap in trj_id 796, splitting to 796 with 306 steps and 56294 with 1131 steps
# Found 138.0 seconds gap in trj_id 56294, splitting to 56294 with 741 steps and 56295 with 390 steps
# Found 139.0 seconds gap in trj_id 56295, splitting to 56295 with 25 steps and 56296 with 365 steps
# Found 100.0 seconds gap in trj_id 800, splitting to 800 with 102 steps and 56297 with 422 steps
# Found 147.0 seconds gap in trj_id 804, splitting to 804 with 2077 steps and 56298 with 347 steps
# Found 74.0 seconds gap in trj_id 806, splitting to 806 with 375 steps and 56299 with 72 steps
# Found 66.0 seconds gap in trj_id 56299, splitting to 56299 with 21 steps and 56300 with 51 steps
# Found 80.0 seconds gap in trj_id 56300, splitting to 56300 with 18 steps and 56301 with 33 steps
# Found 101.0 seconds gap in trj_id 815, splitting to 815 with 1036 steps and 56302 with 712 steps
# Found 90.0 seconds gap in trj_id 827, splitting to 827 with 111 steps and 56303 with 410 steps
# Found 71.0 seconds gap in trj_id 56303, splitting to 56303 with 294 steps and 56304 with 116 steps
# Found 147.0 seconds gap in trj_id 832, splitting to 832 with 285 steps and 56305 with 930 steps
# Found 117.0 seconds gap in trj_id 839, splitting to 839 with 63 steps and 56306 with 361 steps
# Found 126.0 seconds gap in trj_id 847, splitting to 847 with 1065 steps and 56307 with 638 steps
# Found 96.0 seconds gap in trj_id 848, splitting to 848 with 571 steps and 56308 with 412 steps
# Found 115.0 seconds gap in trj_id 857, splitting to 857 with 54 steps and 56309 with 651 steps
# Found 83.0 seconds gap in trj_id 862, splitting to 862 with 142 steps and 56310 with 151 steps
# Found 69.0 seconds gap in trj_id 56310, splitting to 56310 with 31 steps and 56311 with 120 steps
# Found 76.0 seconds gap in trj_id 867, splitting to 867 with 27 steps and 56312 with 541 steps
# Found 84.0 seconds gap in trj_id 56312, splitting to 56312 with 96 steps and 56313 with 445 steps
# Found 78.0 seconds gap in trj_id 56313, splitting to 56313 with 105 steps and 56314 with 340 steps
# Found 85.0 seconds gap in trj_id 869, splitting to 869 with 1404 steps and 56315 with 84 steps
# Found 69.0 seconds gap in trj_id 873, splitting to 873 with 1002 steps and 56316 with 191 steps
# Found 61.0 seconds gap in trj_id 877, splitting to 877 with 448 steps and 56317 with 334 steps
# Found 124.0 seconds gap in trj_id 894, splitting to 894 with 16 steps and 56318 with 1129 steps
# Found 72.0 seconds gap in trj_id 895, splitting to 895 with 811 steps and 56319 with 1212 steps
# Found 314.0 seconds gap in trj_id 902, splitting to 902 with 1047 steps and 56320 with 73 steps
# Found 79.0 seconds gap in trj_id 909, splitting to 909 with 572 steps and 56321 with 471 steps
# Found 128.0 seconds gap in trj_id 910, splitting to 910 with 7 steps and 56322 with 1111 steps
# Found 135.0 seconds gap in trj_id 56322, splitting to 56322 with 185 steps and 56323 with 926 steps
# Found 72.0 seconds gap in trj_id 56323, splitting to 56323 with 511 steps and 56324 with 415 steps
# Found 77.0 seconds gap in trj_id 56324, splitting to 56324 with 59 steps and 56325 with 356 steps
# Found 69.0 seconds gap in trj_id 56325, splitting to 56325 with 298 steps and 56326 with 58 steps
# Found 67.0 seconds gap in trj_id 911, splitting to 911 with 226 steps and 56327 with 326 steps
# Found 63.0 seconds gap in trj_id 912, splitting to 912 with 175 steps and 56328 with 599 steps
# Found 98.0 seconds gap in trj_id 56328, splitting to 56328 with 445 steps and 56329 with 154 steps
# Found 128.0 seconds gap in trj_id 913, splitting to 913 with 3425 steps and 56330 with 316 steps
# Found 66.0 seconds gap in trj_id 917, splitting to 917 with 632 steps and 56331 with 1358 steps
# Found 61.0 seconds gap in trj_id 919, splitting to 919 with 4 steps and 56332 with 449 steps
# Found 61.0 seconds gap in trj_id 56332, splitting to 56332 with 290 steps and 56333 with 159 steps
# Found 77.0 seconds gap in trj_id 922, splitting to 922 with 1163 steps and 56334 with 78 steps
# Found 112.0 seconds gap in trj_id 56334, splitting to 56334 with 33 steps and 56335 with 45 steps
# Found 209.0 seconds gap in trj_id 931, splitting to 931 with 1069 steps and 56336 with 4 steps
# Found 106.0 seconds gap in trj_id 940, splitting to 940 with 392 steps and 56337 with 153 steps
# Found 183.0 seconds gap in trj_id 946, splitting to 946 with 1 steps and 56338 with 609 steps
# Found 276.0 seconds gap in trj_id 56338, splitting to 56338 with 11 steps and 56339 with 598 steps
# Found 129.0 seconds gap in trj_id 953, splitting to 953 with 821 steps and 56340 with 248 steps
# Found 80.0 seconds gap in trj_id 56340, splitting to 56340 with 2 steps and 56341 with 246 steps
# Found 129.0 seconds gap in trj_id 56341, splitting to 56341 with 1 steps and 56342 with 245 steps
# Found 116.0 seconds gap in trj_id 962, splitting to 962 with 1785 steps and 56343 with 57 steps
# Found 96.0 seconds gap in trj_id 966, splitting to 966 with 538 steps and 56344 with 219 steps
# Found 90.0 seconds gap in trj_id 967, splitting to 967 with 253 steps and 56345 with 102 steps
# Found 74.0 seconds gap in trj_id 970, splitting to 970 with 1522 steps and 56346 with 40 steps
# Found 92.0 seconds gap in trj_id 978, splitting to 978 with 473 steps and 56347 with 465 steps
# Found 61.0 seconds gap in trj_id 56347, splitting to 56347 with 405 steps and 56348 with 60 steps
# Found 89.0 seconds gap in trj_id 986, splitting to 986 with 738 steps and 56349 with 1333 steps
# Found 510.0 seconds gap in trj_id 988, splitting to 988 with 37 steps and 56350 with 263 steps
# Found 99.0 seconds gap in trj_id 993, splitting to 993 with 262 steps and 56351 with 701 steps
# Found 65.0 seconds gap in trj_id 996, splitting to 996 with 2009 steps and 56352 with 195 steps
# Found 93.0 seconds gap in trj_id 56352, splitting to 56352 with 27 steps and 56353 with 168 steps
# Found 69.0 seconds gap in trj_id 56353, splitting to 56353 with 8 steps and 56354 with 160 steps
# Found 62.0 seconds gap in trj_id 998, splitting to 998 with 49 steps and 56355 with 388 steps
# Found 87.0 seconds gap in trj_id 999, splitting to 999 with 96 steps and 56356 with 748 steps
# Found 245.0 seconds gap in trj_id 56356, splitting to 56356 with 647 steps and 56357 with 101 steps
# Found 133.0 seconds gap in trj_id 1003, splitting to 1003 with 3957 steps and 56358 with 623 steps
# Found 147.0 seconds gap in trj_id 56358, splitting to 56358 with 145 steps and 56359 with 478 steps
# Found 64.0 seconds gap in trj_id 1014, splitting to 1014 with 37 steps and 56360 with 295 steps
# Found 145.0 seconds gap in trj_id 1022, splitting to 1022 with 158 steps and 56361 with 340 steps
# Found 73.0 seconds gap in trj_id 1026, splitting to 1026 with 586 steps and 56362 with 578 steps
# Found 66.0 seconds gap in trj_id 1029, splitting to 1029 with 98 steps and 56363 with 1085 steps
# Found 106.0 seconds gap in trj_id 1034, splitting to 1034 with 27 steps and 56364 with 1336 steps
# Found 77.0 seconds gap in trj_id 1036, splitting to 1036 with 296 steps and 56365 with 7 steps
# Found 146.0 seconds gap in trj_id 56365, splitting to 56365 with 5 steps and 56366 with 2 steps
# Found 63.0 seconds gap in trj_id 1042, splitting to 1042 with 355 steps and 56367 with 100 steps
# Found 73.0 seconds gap in trj_id 1044, splitting to 1044 with 281 steps and 56368 with 187 steps
# Found 84.0 seconds gap in trj_id 56368, splitting to 56368 with 38 steps and 56369 with 149 steps
# Found 122.0 seconds gap in trj_id 1051, splitting to 1051 with 2 steps and 56370 with 520 steps
# Found 61.0 seconds gap in trj_id 1052, splitting to 1052 with 1237 steps and 56371 with 225 steps
# Found 67.0 seconds gap in trj_id 1068, splitting to 1068 with 1370 steps and 56372 with 412 steps
# Found 64.0 seconds gap in trj_id 1074, splitting to 1074 with 261 steps and 56373 with 41 steps
# Found 70.0 seconds gap in trj_id 1078, splitting to 1078 with 297 steps and 56374 with 165 steps
# Found 68.0 seconds gap in trj_id 1079, splitting to 1079 with 318 steps and 56375 with 264 steps
# Found 65.0 seconds gap in trj_id 1080, splitting to 1080 with 191 steps and 56376 with 450 steps
# Found 61.0 seconds gap in trj_id 1092, splitting to 1092 with 2737 steps and 56377 with 222 steps
# Found 193.0 seconds gap in trj_id 1106, splitting to 1106 with 1271 steps and 56378 with 178 steps
# Found 119.0 seconds gap in trj_id 1108, splitting to 1108 with 1744 steps and 56379 with 438 steps
# Found 124.0 seconds gap in trj_id 1120, splitting to 1120 with 1097 steps and 56380 with 937 steps
# Found 74.0 seconds gap in trj_id 1121, splitting to 1121 with 9 steps and 56381 with 980 steps
# Found 97.0 seconds gap in trj_id 1122, splitting to 1122 with 93 steps and 56382 with 1329 steps
# Found 84.0 seconds gap in trj_id 56382, splitting to 56382 with 1262 steps and 56383 with 67 steps
# Found 81.0 seconds gap in trj_id 56383, splitting to 56383 with 32 steps and 56384 with 35 steps
# Found 87.0 seconds gap in trj_id 1124, splitting to 1124 with 34 steps and 56385 with 229 steps
# Found 110.0 seconds gap in trj_id 1125, splitting to 1125 with 1939 steps and 56386 with 262 steps
# Found 62.0 seconds gap in trj_id 1126, splitting to 1126 with 1775 steps and 56387 with 160 steps
# Found 127.0 seconds gap in trj_id 56387, splitting to 56387 with 61 steps and 56388 with 99 steps
# Found 61.0 seconds gap in trj_id 1129, splitting to 1129 with 4454 steps and 56389 with 49 steps
# Found 78.0 seconds gap in trj_id 1133, splitting to 1133 with 98 steps and 56390 with 392 steps
# Found 61.0 seconds gap in trj_id 1134, splitting to 1134 with 335 steps and 56391 with 879 steps
# Found 116.0 seconds gap in trj_id 1138, splitting to 1138 with 120 steps and 56392 with 1132 steps
# Found 77.0 seconds gap in trj_id 56392, splitting to 56392 with 3 steps and 56393 with 1129 steps
# Found 211.0 seconds gap in trj_id 56393, splitting to 56393 with 1 steps and 56394 with 1128 steps
# Found 69.0 seconds gap in trj_id 1154, splitting to 1154 with 454 steps and 56395 with 1943 steps
# Found 85.0 seconds gap in trj_id 1158, splitting to 1158 with 180 steps and 56396 with 324 steps
# Found 114.0 seconds gap in trj_id 1164, splitting to 1164 with 30 steps and 56397 with 379 steps
# Found 127.0 seconds gap in trj_id 56397, splitting to 56397 with 150 steps and 56398 with 229 steps
# Found 91.0 seconds gap in trj_id 1165, splitting to 1165 with 454 steps and 56399 with 68 steps
# Found 96.0 seconds gap in trj_id 1174, splitting to 1174 with 195 steps and 56400 with 275 steps
# Found 82.0 seconds gap in trj_id 1178, splitting to 1178 with 388 steps and 56401 with 161 steps
# Found 890.0 seconds gap in trj_id 1185, splitting to 1185 with 1148 steps and 56402 with 1410 steps
# Found 115.0 seconds gap in trj_id 56402, splitting to 56402 with 1105 steps and 56403 with 305 steps
# Found 74.0 seconds gap in trj_id 56403, splitting to 56403 with 1 steps and 56404 with 304 steps
# Found 69.0 seconds gap in trj_id 56404, splitting to 56404 with 2 steps and 56405 with 302 steps
# Found 93.0 seconds gap in trj_id 1189, splitting to 1189 with 214 steps and 56406 with 1756 steps
# Found 98.0 seconds gap in trj_id 1190, splitting to 1190 with 148 steps and 56407 with 738 steps
# Found 73.0 seconds gap in trj_id 1191, splitting to 1191 with 20 steps and 56408 with 1952 steps
# Found 85.0 seconds gap in trj_id 56408, splitting to 56408 with 1763 steps and 56409 with 189 steps
# Found 63.0 seconds gap in trj_id 1206, splitting to 1206 with 892 steps and 56410 with 165 steps
# Found 89.0 seconds gap in trj_id 1207, splitting to 1207 with 494 steps and 56411 with 26 steps
# Found 65.0 seconds gap in trj_id 1211, splitting to 1211 with 2058 steps and 56412 with 1273 steps
# Found 111.0 seconds gap in trj_id 56412, splitting to 56412 with 1218 steps and 56413 with 55 steps
# Found 170.0 seconds gap in trj_id 1220, splitting to 1220 with 1 steps and 56414 with 812 steps
# Found 95.0 seconds gap in trj_id 1222, splitting to 1222 with 259 steps and 56415 with 50 steps
# Found 87.0 seconds gap in trj_id 1225, splitting to 1225 with 14 steps and 56416 with 469 steps
# Found 88.0 seconds gap in trj_id 1228, splitting to 1228 with 396 steps and 56417 with 7 steps
# Found 72.0 seconds gap in trj_id 1235, splitting to 1235 with 769 steps and 56418 with 79 steps
# Found 98.0 seconds gap in trj_id 1236, splitting to 1236 with 674 steps and 56419 with 260 steps
# Found 139.0 seconds gap in trj_id 1240, splitting to 1240 with 79 steps and 56420 with 721 steps
# Found 534.0 seconds gap in trj_id 1251, splitting to 1251 with 1490 steps and 56421 with 903 steps
# Found 66.0 seconds gap in trj_id 1252, splitting to 1252 with 412 steps and 56422 with 1 steps
# Found 61.0 seconds gap in trj_id 1256, splitting to 1256 with 2518 steps and 56423 with 33 steps
# Found 156.0 seconds gap in trj_id 56423, splitting to 56423 with 27 steps and 56424 with 6 steps
# Found 86.0 seconds gap in trj_id 1260, splitting to 1260 with 178 steps and 56425 with 515 steps
# Found 73.0 seconds gap in trj_id 1267, splitting to 1267 with 550 steps and 56426 with 379 steps
# Found 73.0 seconds gap in trj_id 1271, splitting to 1271 with 183 steps and 56427 with 401 steps
# Found 80.0 seconds gap in trj_id 56427, splitting to 56427 with 184 steps and 56428 with 217 steps
# Found 78.0 seconds gap in trj_id 56428, splitting to 56428 with 162 steps and 56429 with 55 steps
# Found 81.0 seconds gap in trj_id 1272, splitting to 1272 with 885 steps and 56430 with 75 steps
# Found 111.0 seconds gap in trj_id 1273, splitting to 1273 with 3632 steps and 56431 with 69 steps
# Found 62.0 seconds gap in trj_id 56431, splitting to 56431 with 17 steps and 56432 with 52 steps
# Found 61.0 seconds gap in trj_id 1274, splitting to 1274 with 405 steps and 56433 with 214 steps
# Found 79.0 seconds gap in trj_id 1275, splitting to 1275 with 821 steps and 56434 with 1133 steps
# Found 66.0 seconds gap in trj_id 56434, splitting to 56434 with 179 steps and 56435 with 954 steps
# Found 84.0 seconds gap in trj_id 56435, splitting to 56435 with 299 steps and 56436 with 655 steps
# Found 81.0 seconds gap in trj_id 1284, splitting to 1284 with 207 steps and 56437 with 378 steps
# Found 139.0 seconds gap in trj_id 1290, splitting to 1290 with 417 steps and 56438 with 59 steps
# Found 66.0 seconds gap in trj_id 1294, splitting to 1294 with 1177 steps and 56439 with 1832 steps
# Found 1179.0 seconds gap in trj_id 56439, splitting to 56439 with 78 steps and 56440 with 1754 steps
# Found 82.0 seconds gap in trj_id 56440, splitting to 56440 with 1200 steps and 56441 with 554 steps
# Found 128.0 seconds gap in trj_id 56441, splitting to 56441 with 61 steps and 56442 with 493 steps
# Found 148.0 seconds gap in trj_id 1295, splitting to 1295 with 12 steps and 56443 with 514 steps
# Found 80.0 seconds gap in trj_id 1300, splitting to 1300 with 136 steps and 56444 with 2007 steps
# Found 120.0 seconds gap in trj_id 56444, splitting to 56444 with 1997 steps and 56445 with 10 steps
# Found 135.0 seconds gap in trj_id 1302, splitting to 1302 with 870 steps and 56446 with 27 steps
# Found 295.0 seconds gap in trj_id 1310, splitting to 1310 with 10 steps and 56447 with 435 steps
# Found 64.0 seconds gap in trj_id 1312, splitting to 1312 with 323 steps and 56448 with 155 steps
# Found 65.0 seconds gap in trj_id 1314, splitting to 1314 with 63 steps and 56449 with 295 steps
# Found 89.0 seconds gap in trj_id 56449, splitting to 56449 with 230 steps and 56450 with 65 steps
# Found 262.0 seconds gap in trj_id 1315, splitting to 1315 with 136 steps and 56451 with 859 steps
# Found 249.0 seconds gap in trj_id 1326, splitting to 1326 with 24 steps and 56452 with 670 steps
# Found 67.0 seconds gap in trj_id 1329, splitting to 1329 with 449 steps and 56453 with 168 steps
# Found 67.0 seconds gap in trj_id 1332, splitting to 1332 with 324 steps and 56454 with 1172 steps
# Found 175.0 seconds gap in trj_id 56454, splitting to 56454 with 962 steps and 56455 with 210 steps
# Found 68.0 seconds gap in trj_id 56455, splitting to 56455 with 7 steps and 56456 with 203 steps
# Found 385.0 seconds gap in trj_id 56456, splitting to 56456 with 8 steps and 56457 with 195 steps
# Found 76.0 seconds gap in trj_id 1334, splitting to 1334 with 414 steps and 56458 with 195 steps
# Found 63.0 seconds gap in trj_id 1335, splitting to 1335 with 126 steps and 56459 with 262 steps
# Found 64.0 seconds gap in trj_id 1337, splitting to 1337 with 516 steps and 56460 with 445 steps
# Found 102.0 seconds gap in trj_id 1340, splitting to 1340 with 273 steps and 56461 with 138 steps
# Found 63.0 seconds gap in trj_id 1346, splitting to 1346 with 863 steps and 56462 with 374 steps
# Found 315.0 seconds gap in trj_id 1352, splitting to 1352 with 29 steps and 56463 with 430 steps
# Found 91.0 seconds gap in trj_id 1355, splitting to 1355 with 137 steps and 56464 with 990 steps
# Found 74.0 seconds gap in trj_id 56464, splitting to 56464 with 202 steps and 56465 with 788 steps
# Found 315.0 seconds gap in trj_id 1356, splitting to 1356 with 130 steps and 56466 with 858 steps
# Found 67.0 seconds gap in trj_id 1359, splitting to 1359 with 290 steps and 56467 with 329 steps
# Found 73.0 seconds gap in trj_id 56467, splitting to 56467 with 100 steps and 56468 with 229 steps
# Found 102.0 seconds gap in trj_id 56468, splitting to 56468 with 219 steps and 56469 with 10 steps
# Found 80.0 seconds gap in trj_id 1369, splitting to 1369 with 772 steps and 56470 with 75 steps
# Found 61.0 seconds gap in trj_id 1370, splitting to 1370 with 1642 steps and 56471 with 346 steps
# Found 105.0 seconds gap in trj_id 56471, splitting to 56471 with 79 steps and 56472 with 267 steps
# Found 64.0 seconds gap in trj_id 1373, splitting to 1373 with 405 steps and 56473 with 320 steps
# Found 69.0 seconds gap in trj_id 1375, splitting to 1375 with 118 steps and 56474 with 665 steps
# Found 69.0 seconds gap in trj_id 56474, splitting to 56474 with 58 steps and 56475 with 607 steps
# Found 76.0 seconds gap in trj_id 56475, splitting to 56475 with 1 steps and 56476 with 606 steps
# Found 66.0 seconds gap in trj_id 1376, splitting to 1376 with 990 steps and 56477 with 1610 steps
# Found 128.0 seconds gap in trj_id 1377, splitting to 1377 with 86 steps and 56478 with 539 steps
# Found 92.0 seconds gap in trj_id 1379, splitting to 1379 with 90 steps and 56479 with 812 steps
# Found 68.0 seconds gap in trj_id 56479, splitting to 56479 with 203 steps and 56480 with 609 steps
# Found 90.0 seconds gap in trj_id 56480, splitting to 56480 with 199 steps and 56481 with 410 steps
# ...
# Found 73.0 seconds gap in trj_id 75668, splitting to 75668 with 29 steps and 75669 with 117 steps
# Found 69.0 seconds gap in trj_id 55497, splitting to 55497 with 397 steps and 75670 with 783 steps
# Found 153.0 seconds gap in trj_id 55501, splitting to 55501 with 419 steps and 75671 with 277 steps
# Found 61.0 seconds gap in trj_id 75671, splitting to 75671 with 63 steps and 75672 with 214 steps
# Found 77.0 seconds gap in trj_id 55502, splitting to 55502 with 561 steps and 75673 with 469 steps
# Found 551.0 seconds gap in trj_id 55505, splitting to 55505 with 1 steps and 75674 with 301 steps
# Found 86.0 seconds gap in trj_id 75674, splitting to 75674 with 1 steps and 75675 with 300 steps
# Found 79.0 seconds gap in trj_id 75675, splitting to 75675 with 2 steps and 75676 with 298 steps
# Found 74.0 seconds gap in trj_id 55506, splitting to 55506 with 115 steps and 75677 with 1029 steps
# Found 75.0 seconds gap in trj_id 75677, splitting to 75677 with 198 steps and 75678 with 831 steps
# Found 119.0 seconds gap in trj_id 55507, splitting to 55507 with 801 steps and 75679 with 67 steps
# Found 103.0 seconds gap in trj_id 75679, splitting to 75679 with 35 steps and 75680 with 32 steps
# Found 70.0 seconds gap in trj_id 55509, splitting to 55509 with 1368 steps and 75681 with 127 steps
# Found 106.0 seconds gap in trj_id 55514, splitting to 55514 with 1095 steps and 75682 with 50 steps
# Found 77.0 seconds gap in trj_id 55517, splitting to 55517 with 644 steps and 75683 with 92 steps
# Found 162.0 seconds gap in trj_id 55529, splitting to 55529 with 431 steps and 75684 with 5833 steps
# Found 182.0 seconds gap in trj_id 75684, splitting to 75684 with 3110 steps and 75685 with 2723 steps
# Found 130.0 seconds gap in trj_id 55530, splitting to 55530 with 375 steps and 75686 with 35 steps
# Found 164.0 seconds gap in trj_id 55531, splitting to 55531 with 388 steps and 75687 with 1 steps
# Found 61.0 seconds gap in trj_id 55534, splitting to 55534 with 262 steps and 75688 with 1182 steps
# Found 61.0 seconds gap in trj_id 55541, splitting to 55541 with 574 steps and 75689 with 416 steps
# Found 96.0 seconds gap in trj_id 55562, splitting to 55562 with 699 steps and 75690 with 307 steps
# Found 110.0 seconds gap in trj_id 55574, splitting to 55574 with 3317 steps and 75691 with 667 steps
# Found 124.0 seconds gap in trj_id 75691, splitting to 75691 with 70 steps and 75692 with 597 steps
# Found 63.0 seconds gap in trj_id 75692, splitting to 75692 with 1 steps and 75693 with 596 steps
# Found 61.0 seconds gap in trj_id 55577, splitting to 55577 with 231 steps and 75694 with 173 steps
# Found 95.0 seconds gap in trj_id 55578, splitting to 55578 with 2 steps and 75695 with 302 steps
# Found 98.0 seconds gap in trj_id 55581, splitting to 55581 with 1 steps and 75696 with 730 steps
# Found 75.0 seconds gap in trj_id 75696, splitting to 75696 with 92 steps and 75697 with 638 steps
# Found 72.0 seconds gap in trj_id 55582, splitting to 55582 with 417 steps and 75698 with 666 steps
# Found 65.0 seconds gap in trj_id 55585, splitting to 55585 with 638 steps and 75699 with 280 steps
# Found 95.0 seconds gap in trj_id 55592, splitting to 55592 with 419 steps and 75700 with 820 steps
# Found 129.0 seconds gap in trj_id 55605, splitting to 55605 with 116 steps and 75701 with 248 steps
# Found 168.0 seconds gap in trj_id 55606, splitting to 55606 with 2709 steps and 75702 with 4 steps
# Found 61.0 seconds gap in trj_id 55607, splitting to 55607 with 854 steps and 75703 with 1241 steps
# Found 62.0 seconds gap in trj_id 55608, splitting to 55608 with 799 steps and 75704 with 120 steps
# Found 93.0 seconds gap in trj_id 55615, splitting to 55615 with 282 steps and 75705 with 1709 steps
# Found 65.0 seconds gap in trj_id 55617, splitting to 55617 with 265 steps and 75706 with 101 steps
# Found 86.0 seconds gap in trj_id 55620, splitting to 55620 with 892 steps and 75707 with 116 steps
# Found 68.0 seconds gap in trj_id 55623, splitting to 55623 with 102 steps and 75708 with 1163 steps
# Found 113.0 seconds gap in trj_id 55627, splitting to 55627 with 824 steps and 75709 with 264 steps
# Found 75.0 seconds gap in trj_id 55628, splitting to 55628 with 280 steps and 75710 with 368 steps
# Found 167.0 seconds gap in trj_id 75710, splitting to 75710 with 189 steps and 75711 with 179 steps
# Found 86.0 seconds gap in trj_id 55631, splitting to 55631 with 137 steps and 75712 with 698 steps
# Found 66.0 seconds gap in trj_id 55634, splitting to 55634 with 252 steps and 75713 with 783 steps
# Found 147.0 seconds gap in trj_id 55642, splitting to 55642 with 747 steps and 75714 with 17 steps
# Found 64.0 seconds gap in trj_id 55654, splitting to 55654 with 647 steps and 75715 with 135 steps
# Found 63.0 seconds gap in trj_id 75715, splitting to 75715 with 26 steps and 75716 with 109 steps
# Found 94.0 seconds gap in trj_id 55659, splitting to 55659 with 40 steps and 75717 with 440 steps
# Found 78.0 seconds gap in trj_id 55664, splitting to 55664 with 3333 steps and 75718 with 337 steps
# Found 76.0 seconds gap in trj_id 55670, splitting to 55670 with 441 steps and 75719 with 288 steps
# Found 83.0 seconds gap in trj_id 55673, splitting to 55673 with 142 steps and 75720 with 270 steps
# Found 62.0 seconds gap in trj_id 55677, splitting to 55677 with 354 steps and 75721 with 302 steps
# Found 400.0 seconds gap in trj_id 55678, splitting to 55678 with 80 steps and 75722 with 1619 steps
# Found 117.0 seconds gap in trj_id 55679, splitting to 55679 with 545 steps and 75723 with 425 steps
# Found 100.0 seconds gap in trj_id 55680, splitting to 55680 with 70 steps and 75724 with 483 steps
# Found 67.0 seconds gap in trj_id 75724, splitting to 75724 with 396 steps and 75725 with 87 steps
# Found 95.0 seconds gap in trj_id 55687, splitting to 55687 with 307 steps and 75726 with 161 steps
# Found 196.0 seconds gap in trj_id 55689, splitting to 55689 with 37 steps and 75727 with 219 steps
# Found 794.0 seconds gap in trj_id 75727, splitting to 75727 with 29 steps and 75728 with 190 steps
# Found 202.0 seconds gap in trj_id 75728, splitting to 75728 with 1 steps and 75729 with 189 steps
# Found 92.0 seconds gap in trj_id 75729, splitting to 75729 with 1 steps and 75730 with 188 steps
# Found 65.0 seconds gap in trj_id 75730, splitting to 75730 with 52 steps and 75731 with 136 steps
# Found 67.0 seconds gap in trj_id 55696, splitting to 55696 with 1182 steps and 75732 with 493 steps
# Found 72.0 seconds gap in trj_id 75732, splitting to 75732 with 344 steps and 75733 with 149 steps
# Found 92.0 seconds gap in trj_id 75733, splitting to 75733 with 126 steps and 75734 with 23 steps
# Found 96.0 seconds gap in trj_id 55698, splitting to 55698 with 877 steps and 75735 with 3636 steps
# Found 68.0 seconds gap in trj_id 75735, splitting to 75735 with 34 steps and 75736 with 3602 steps
# Found 226.0 seconds gap in trj_id 75736, splitting to 75736 with 10 steps and 75737 with 3592 steps
# Found 826.0 seconds gap in trj_id 75737, splitting to 75737 with 3189 steps and 75738 with 403 steps
# Found 111.0 seconds gap in trj_id 55699, splitting to 55699 with 716 steps and 75739 with 177 steps
# Found 93.0 seconds gap in trj_id 55700, splitting to 55700 with 271 steps and 75740 with 2268 steps
# Found 86.0 seconds gap in trj_id 75740, splitting to 75740 with 171 steps and 75741 with 2097 steps
# Found 91.0 seconds gap in trj_id 75741, splitting to 75741 with 75 steps and 75742 with 2022 steps
# Found 174.0 seconds gap in trj_id 75742, splitting to 75742 with 34 steps and 75743 with 1988 steps
# Found 144.0 seconds gap in trj_id 55706, splitting to 55706 with 464 steps and 75744 with 65 steps
# Found 242.0 seconds gap in trj_id 55709, splitting to 55709 with 382 steps and 75745 with 140 steps
# Found 69.0 seconds gap in trj_id 55710, splitting to 55710 with 98 steps and 75746 with 380 steps
# Found 112.0 seconds gap in trj_id 55711, splitting to 55711 with 24 steps and 75747 with 413 steps
# Found 67.0 seconds gap in trj_id 55714, splitting to 55714 with 313 steps and 75748 with 682 steps
# Found 81.0 seconds gap in trj_id 55715, splitting to 55715 with 548 steps and 75749 with 318 steps
# Found 96.0 seconds gap in trj_id 55720, splitting to 55720 with 669 steps and 75750 with 573 steps
# Found 76.0 seconds gap in trj_id 55724, splitting to 55724 with 307 steps and 75751 with 578 steps
# Found 102.0 seconds gap in trj_id 55725, splitting to 55725 with 711 steps and 75752 with 68 steps
# Found 132.0 seconds gap in trj_id 55732, splitting to 55732 with 24 steps and 75753 with 372 steps
# Found 76.0 seconds gap in trj_id 55743, splitting to 55743 with 300 steps and 75754 with 788 steps
# Found 208.0 seconds gap in trj_id 75754, splitting to 75754 with 694 steps and 75755 with 94 steps
# Found 92.0 seconds gap in trj_id 55748, splitting to 55748 with 943 steps and 75756 with 1373 steps
# Found 317.0 seconds gap in trj_id 55750, splitting to 55750 with 1143 steps and 75757 with 230 steps
# Found 175.0 seconds gap in trj_id 55753, splitting to 55753 with 439 steps and 75758 with 393 steps
# Found 112.0 seconds gap in trj_id 55764, splitting to 55764 with 175 steps and 75759 with 368 steps
# Found 69.0 seconds gap in trj_id 55767, splitting to 55767 with 576 steps and 75760 with 332 steps
# Found 63.0 seconds gap in trj_id 75760, splitting to 75760 with 67 steps and 75761 with 265 steps
# Found 62.0 seconds gap in trj_id 55769, splitting to 55769 with 591 steps and 75762 with 296 steps
# Found 78.0 seconds gap in trj_id 55784, splitting to 55784 with 1111 steps and 75763 with 110 steps
# Found 67.0 seconds gap in trj_id 55785, splitting to 55785 with 83 steps and 75764 with 570 steps
# Found 128.0 seconds gap in trj_id 55796, splitting to 55796 with 533 steps and 75765 with 447 steps
# Found 160.0 seconds gap in trj_id 55799, splitting to 55799 with 504 steps and 75766 with 91 steps
# Found 89.0 seconds gap in trj_id 55809, splitting to 55809 with 52 steps and 75767 with 392 steps
# Found 64.0 seconds gap in trj_id 55810, splitting to 55810 with 636 steps and 75768 with 410 steps
# Found 87.0 seconds gap in trj_id 55812, splitting to 55812 with 576 steps and 75769 with 310 steps
# Found 61.0 seconds gap in trj_id 55822, splitting to 55822 with 1046 steps and 75770 with 751 steps
# Found 113.0 seconds gap in trj_id 55824, splitting to 55824 with 43 steps and 75771 with 357 steps
# Found 63.0 seconds gap in trj_id 75771, splitting to 75771 with 112 steps and 75772 with 245 steps
# Found 77.0 seconds gap in trj_id 55838, splitting to 55838 with 833 steps and 75773 with 319 steps
# Found 111.0 seconds gap in trj_id 55840, splitting to 55840 with 702 steps and 75774 with 3 steps
# Found 67.0 seconds gap in trj_id 75774, splitting to 75774 with 2 steps and 75775 with 1 steps
# Found 72.0 seconds gap in trj_id 55842, splitting to 55842 with 2044 steps and 75776 with 355 steps
# Found 103.0 seconds gap in trj_id 55844, splitting to 55844 with 189 steps and 75777 with 966 steps
# Found 62.0 seconds gap in trj_id 55845, splitting to 55845 with 149 steps and 75778 with 371 steps
# Found 106.0 seconds gap in trj_id 75778, splitting to 75778 with 336 steps and 75779 with 35 steps
# Found 72.0 seconds gap in trj_id 55846, splitting to 55846 with 29 steps and 75780 with 3972 steps
# Found 126.0 seconds gap in trj_id 75780, splitting to 75780 with 1925 steps and 75781 with 2047 steps
# Found 97.0 seconds gap in trj_id 55848, splitting to 55848 with 470 steps and 75782 with 12 steps
# Found 94.0 seconds gap in trj_id 55850, splitting to 55850 with 123 steps and 75783 with 2966 steps
# Found 101.0 seconds gap in trj_id 55851, splitting to 55851 with 655 steps and 75784 with 1920 steps
# Found 83.0 seconds gap in trj_id 55853, splitting to 55853 with 176 steps and 75785 with 166 steps
# Found 107.0 seconds gap in trj_id 75785, splitting to 75785 with 88 steps and 75786 with 78 steps
# Found 101.0 seconds gap in trj_id 55854, splitting to 55854 with 2723 steps and 75787 with 263 steps
# Found 68.0 seconds gap in trj_id 55870, splitting to 55870 with 274 steps and 75788 with 174 steps
# Found 75.0 seconds gap in trj_id 55871, splitting to 55871 with 186 steps and 75789 with 251 steps
# Found 84.0 seconds gap in trj_id 55881, splitting to 55881 with 300 steps and 75790 with 724 steps
# Found 70.0 seconds gap in trj_id 55882, splitting to 55882 with 389 steps and 75791 with 250 steps
# Found 101.0 seconds gap in trj_id 55883, splitting to 55883 with 370 steps and 75792 with 11 steps
# Found 90.0 seconds gap in trj_id 55900, splitting to 55900 with 381 steps and 75793 with 1642 steps
# Found 64.0 seconds gap in trj_id 55903, splitting to 55903 with 385 steps and 75794 with 247 steps
# Found 74.0 seconds gap in trj_id 75794, splitting to 75794 with 149 steps and 75795 with 98 steps
# Found 71.0 seconds gap in trj_id 75795, splitting to 75795 with 81 steps and 75796 with 17 steps
# Found 74.0 seconds gap in trj_id 55907, splitting to 55907 with 1236 steps and 75797 with 201 steps
# Found 66.0 seconds gap in trj_id 55911, splitting to 55911 with 14 steps and 75798 with 513 steps
# Found 77.0 seconds gap in trj_id 55915, splitting to 55915 with 903 steps and 75799 with 2935 steps
# Found 73.0 seconds gap in trj_id 55916, splitting to 55916 with 93 steps and 75800 with 1060 steps
# Found 65.0 seconds gap in trj_id 75800, splitting to 75800 with 975 steps and 75801 with 85 steps
# Found 91.0 seconds gap in trj_id 55919, splitting to 55919 with 47 steps and 75802 with 401 steps
# Found 106.0 seconds gap in trj_id 75802, splitting to 75802 with 18 steps and 75803 with 383 steps
# Found 91.0 seconds gap in trj_id 75803, splitting to 75803 with 11 steps and 75804 with 372 steps
# Found 266.0 seconds gap in trj_id 55924, splitting to 55924 with 115 steps and 75805 with 537 steps
# Found 205.0 seconds gap in trj_id 55925, splitting to 55925 with 889 steps and 75806 with 222 steps
# Found 84.0 seconds gap in trj_id 55926, splitting to 55926 with 266 steps and 75807 with 205 steps
# Found 107.0 seconds gap in trj_id 55930, splitting to 55930 with 138 steps and 75808 with 571 steps
# Found 70.0 seconds gap in trj_id 75808, splitting to 75808 with 285 steps and 75809 with 286 steps
# Found 68.0 seconds gap in trj_id 55932, splitting to 55932 with 208 steps and 75810 with 200 steps
# Found 122.0 seconds gap in trj_id 55936, splitting to 55936 with 417 steps and 75811 with 5 steps
# Found 87.0 seconds gap in trj_id 55940, splitting to 55940 with 1460 steps and 75812 with 9 steps
# Found 68.0 seconds gap in trj_id 55943, splitting to 55943 with 1045 steps and 75813 with 26 steps
# Found 91.0 seconds gap in trj_id 55947, splitting to 55947 with 3781 steps and 75814 with 256 steps
# Found 87.0 seconds gap in trj_id 55952, splitting to 55952 with 45 steps and 75815 with 2140 steps
# Found 153.0 seconds gap in trj_id 55955, splitting to 55955 with 1195 steps and 75816 with 98 steps
# Found 87.0 seconds gap in trj_id 55958, splitting to 55958 with 221 steps and 75817 with 120 steps
# Found 113.0 seconds gap in trj_id 55966, splitting to 55966 with 1665 steps and 75818 with 1011 steps
# Found 161.0 seconds gap in trj_id 55968, splitting to 55968 with 74 steps and 75819 with 314 steps
# Found 108.0 seconds gap in trj_id 75819, splitting to 75819 with 288 steps and 75820 with 26 steps
# Found 127.0 seconds gap in trj_id 75820, splitting to 75820 with 22 steps and 75821 with 4 steps
# Found 68.0 seconds gap in trj_id 55975, splitting to 55975 with 886 steps and 75822 with 451 steps
# Found 74.0 seconds gap in trj_id 55976, splitting to 55976 with 255 steps and 75823 with 2811 steps
# Found 68.0 seconds gap in trj_id 75823, splitting to 75823 with 2755 steps and 75824 with 56 steps
# Found 99.0 seconds gap in trj_id 55979, splitting to 55979 with 122 steps and 75825 with 185 steps
# Found 174.0 seconds gap in trj_id 75825, splitting to 75825 with 5 steps and 75826 with 180 steps
# Found 91.0 seconds gap in trj_id 55982, splitting to 55982 with 97 steps and 75827 with 1056 steps
# Found 191.0 seconds gap in trj_id 75827, splitting to 75827 with 457 steps and 75828 with 599 steps
# Found 208.0 seconds gap in trj_id 75828, splitting to 75828 with 2 steps and 75829 with 597 steps
# 55995
# 75829

# %%
def remove_large_gaps(df, gap_seconds=10):
    # Function to check for large gaps within a group
    def has_large_gaps(group):
        time_diff = group['pingtimestamp'].diff()
        return (time_diff > pd.Timedelta(seconds=gap_seconds)).any()

    # Find index (trj_id) values with large gaps
    trj_ids_with_gaps = df.groupby(df.index).filter(has_large_gaps).index.unique()

    # Remove rows with those trj_ids
    cleaned_df = df[~df.index.isin(trj_ids_with_gaps)]
    
    return cleaned_df

# Example usage:
# Assuming df is the DataFrame from the previous step with 'trj_id' set as the index
pruned_df = remove_large_gaps(split_df, gap_seconds=30)

# %%
# Make hour_of_day and day_of_week from pingtimestamp (Used so the model can better predict user movement from time of day and day of week)
pruned_df['minute_of_hour'] = pruned_df['pingtimestamp'].dt.minute
pruned_df['hour_of_day'] = pruned_df['pingtimestamp'].dt.hour
pruned_df['day_of_week'] = pruned_df['pingtimestamp'].dt.dayofweek
pruned_df = pruned_df.drop('pingtimestamp', axis=1) # Drop pingtimestamp as it is no longer needed
print(pruned_df)
# Out:
# C:\Users\adrie\AppData\Local\Temp\ipykernel_31488\3336230561.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pruned_df['minute_of_hour'] = pruned_df['pingtimestamp'].dt.minute
# C:\Users\adrie\AppData\Local\Temp\ipykernel_31488\3336230561.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pruned_df['hour_of_day'] = pruned_df['pingtimestamp'].dt.hour
# C:\Users\adrie\AppData\Local\Temp\ipykernel_31488\3336230561.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pruned_df['day_of_week'] = pruned_df['pingtimestamp'].dt.dayofweek
#           rawlat      rawlng  speed  bearing  minute_of_hour  hour_of_day  \
# trj_id
# 2      -6.248311  106.930447  11.35       88              51            0
# 2      -6.248345  106.930673  12.43       87              51            0
# 2      -6.248374  106.930931  13.83       84              51            0
# 2      -6.248391  106.931061  14.29       85              51            0
# 2      -6.248410  106.931184  14.58       87              51            0
# ...          ...         ...    ...      ...             ...          ...
# 55995  -6.178844  106.841960   0.00        0              57            4
# 55995  -6.178844  106.841960   0.00        0              57            4
# 55995  -6.178844  106.841961   0.00        0              57            4
# 55995  -6.178845  106.841963   0.00        0              57            4
# 55995  -6.178845  106.841964   0.00        0              57            4
#
#         day_of_week
# trj_id
# 2                 1
# 2                 1
# 2                 1
# 2                 1
# 2                 1
# ...             ...
# 55995             6
# 55995             6
# 55995             6
# 55995             6
# 55995             6
#
# [34839771 rows x 7 columns]

# %%
# Export data to Parquet
pruned_df.to_parquet('clean_non_resampled_data.parquet')
